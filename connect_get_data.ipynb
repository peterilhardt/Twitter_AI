# %%
import pandas as pd
import numpy as np
import requests
import tweepy  # best for Twitter Standard API
from TwitterAPI import TwitterAPI  # needed for Twitter Premium API access
from requests_oauthlib import OAuth1
from pprint import pprint
import pickle
from pymongo import MongoClient

from twitter_api_functions import tweet_to_string, tweets_to_df, get_tweets_premium

# %%
# need to have Twitter Developer account in order for this to work (https://developer.twitter.com)
# see setup_twitter_instructions.md below for further instructions 

from twitter_credentials import credentials

oauth = OAuth1(credentials["TWITTER_CONSUMER_KEY"],
               credentials["TWITTER_CONSUMER_KEY_SECRET"],
               credentials["TWITTER_ACCESS_TOKEN"],
               credentials["TWITTER_ACCESS_TOKEN_SECRET"])

# %% [markdown]
# See [this file](./setup_twitter_instructions.md) for step-by-step instructions on how to setup a Twitter app and get access tokens.

# %%
# test query of Twitter API using requests (get current tweets from @thisismetis)
response = requests.get("https://api.twitter.com/1.1/search/tweets.json?q=%40thisismetis",
                        auth = oauth)

tweets = response.json()
list(tweets.keys())
# Out:
# ['statuses', 'search_metadata']

# %%
pprint(tweets['statuses'][0])
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Aug 24 23:02:29 +0000 2019',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 2233022917,
#                                  'id_str': '2233022917',
#                                  'indices': [3, 15],
#                                  'name': 'Metis',
#                                  'screen_name': 'thisismetis'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1165399003271434241,
#  'id_str': '1165399003271434241',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 1,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Sat Aug 24 23:00:06 +0000 2019',
#                       'entities': {'hashtags': [],
#                                    'symbols': [],
#                                    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                              'expanded_url': 'https://twitter.com/i/web/status/1165398403817332736',
#                                              'indices': [117, 140],
#                                              'url': 'https://t.co/TPTtxatDQJ'}],
#                                    'user_mentions': []},
#                       'favorite_count': 1,
#                       'favorited': False,
#                       'geo': None,
#                       'id': 1165398403817332736,
#                       'id_str': '1165398403817332736',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'is_quote_status': False,
#                       'lang': 'en',
#                       'metadata': {'iso_language_code': 'en',
#                                    'result_type': 'recent'},
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'retweet_count': 1,
#                       'retweeted': False,
#                       'source': '<a href="https://sproutsocial.com" '
#                                 'rel="nofollow">Sprout Social</a>',
#                       'text': 'On 9/4, join us live on our Community Slack '
#                               'Channel for an Ask Me Anything session with '
#                               'Nathan Grossman, Data Scien… '
#                               'https://t.co/TPTtxatDQJ',
#                       'truncated': True,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Fri Dec 06 13:52:35 +0000 2013',
#                                'default_profile': False,
#                                'default_profile_image': False,
#                                'description': 'Metis accelerates careers in '
#                                               'data science by providing '
#                                               'immersive bootcamps, '
#                                               'professional development '
#                                               'courses, online resources, and '
#                                               'corporate training.',
#                                'entities': {'description': {'urls': []},
#                                             'url': {'urls': [{'display_url': 'thisismetis.com',
#                                                               'expanded_url': 'http://thisismetis.com',
#                                                               'indices': [0,
#                                                                           23],
#                                                               'url': 'https://t.co/T7tjeGuAO0'}]}},
#                                'favourites_count': 3759,
#                                'follow_request_sent': False,
#                                'followers_count': 6363,
#                                'following': False,
#                                'friends_count': 1725,
#                                'geo_enabled': True,
#                                'has_extended_profile': False,
#                                'id': 2233022917,
#                                'id_str': '2233022917',
#                                'is_translation_enabled': False,
#                                'is_translator': False,
#                                'lang': None,
#                                'listed_count': 442,
#                                'location': 'NYC, SF, Chicago, Seattle, '
#                                            'Singapore, Live Online',
#                                'name': 'Metis',
#                                'notifications': False,
#                                'profile_background_color': '000000',
#                                'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2233022917/1564673097',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000847016011/9b177e2d834ca173f88ae26d39fdae74_normal.png',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000847016011/9b177e2d834ca173f88ae26d39fdae74_normal.png',
#                                'profile_link_color': '489CDA',
#                                'profile_sidebar_border_color': 'FFFFFF',
#                                'profile_sidebar_fill_color': 'DDEEF6',
#                                'profile_text_color': '333333',
#                                'profile_use_background_image': False,
#                                'protected': False,
#                                'screen_name': 'thisismetis',
#                                'statuses_count': 12039,
#                                'time_zone': None,
#                                'translator_type': 'none',
#                                'url': 'https://t.co/T7tjeGuAO0',
#                                'utc_offset': None,
#                                'verified': False}},
#  'source': '<a href="http://www.insomniachat.com" rel="nofollow">spoken word '
#            'vincent</a>',
#  'text': 'RT @thisismetis: On 9/4, join us live on our Community Slack Channel '
#          'for an Ask Me Anything session with Nathan Grossman, Data Scientist '
#          'at…',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Mon Jan 26 15:43:29 +0000 2009',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Mentalist Poet, Digital Data Activist, Writer, '
#                          'Satirist. #cunningLinguist monitoring data-driven '
#                          'political, social & behavioral change marketing & '
#                          'communication',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'sleeplessdystopian.com',
#                                          'expanded_url': 'http://sleeplessdystopian.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/yabJ8ODgf6'}]}},
#           'favourites_count': 264,
#           'follow_request_sent': False,
#           'followers_count': 1416,
#           'following': False,
#           'friends_count': 1102,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 19539923,
#           'id_str': '19539923',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': None,
#           'listed_count': 70,
#           'location': 'Shropshire',
#           'name': 'dystopian mentalist',
#           'notifications': False,
#           'profile_background_color': '1A1B1F',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19539923/1433070750',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg',
#           'profile_link_color': '2FC2EF',
#           'profile_sidebar_border_color': '181A1E',
#           'profile_sidebar_fill_color': '252429',
#           'profile_text_color': '666666',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'JustBeMentalist',
#           'statuses_count': 46963,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/yabJ8ODgf6',
#           'utc_offset': None,
#           'verified': False}}

# %%
list(tweets['statuses'][0].keys())
# Out:
# ['created_at',
#  'id',
#  'id_str',
#  'text',
#  'truncated',
#  'entities',
#  'metadata',
#  'source',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'in_reply_to_screen_name',
#  'user',
#  'geo',
#  'coordinates',
#  'place',
#  'contributors',
#  'retweeted_status',
#  'is_quote_status',
#  'retweet_count',
#  'favorite_count',
#  'favorited',
#  'retweeted',
#  'lang']

# %%
pprint(tweets['search_metadata'])
# Out:
# {'completed_in': 0.048,
#  'count': 15,
#  'max_id': 1165399003271434241,
#  'max_id_str': '1165399003271434241',
#  'next_results': '?max_id=1164187044270223360&q=%40thisismetis&include_entities=1',
#  'query': '%40thisismetis',
#  'refresh_url': '?since_id=1165399003271434241&q=%40thisismetis&include_entities=1',
#  'since_id': 0,
#  'since_id_str': '0'}

# %%
# get 5 tweets with keywords 'Artificial Intelligence'
parameters = {"q": "Artificial Intelligence", "count": 5, "lang": "en"}
url = "https://api.twitter.com/1.1/search/tweets.json"

response = requests.get(url, params = parameters, auth = oauth)

tweets = response.json()['statuses']
for tweet in tweets:
    print(tweet_to_string(tweet).strip())
    print('\n')
# Out:
# Text: RT @KirkDBorne: The Black Box — Explainable Artificial Intelligence #XAI and the Limits of Human Deliberative Processes: https://t.co/VYs43…
#         Hashtags: [{'text': 'XAI', 'indices': [68, 72]}]
#         Name: Robert Navarro
#         Username: damarafaka
#         User Description: Beyond the abyss, free thinker, simulations, provocateur, reverse engineering, security consultant; e-wheel & another algorithm War
#         Social Status: 766 friends, 239 followers, 8488 favorites
#         Location:
#         Geocode: None
#         Date: Sun Aug 25 00:40:33 +0000 2019
#
#
# Text: RT @nordicinst: Scientist to Hollywood: Artificial Intelligence Doesn't Work the Way You Think it Does. #aiethics #MachineLearning #aiforgo…
#         Hashtags: [{'text': 'aiethics', 'indices': [104, 113]}, {'text': 'MachineLearning', 'indices': [114, 130]}]
#         Name: Benjamin Huskinson
#         Username: Benhuskinson
#         User Description: Historian of science and religion. Aggressively pro-brunch.
#         Social Status: 69 friends, 10 followers, 0 favorites
#         Location:
#         Geocode: None
#         Date: Sun Aug 25 00:40:04 +0000 2019
#
#
# Text: RT @USATODAY: The increasing prevalence of Artificial Intelligence has boosted efficiency and reduced costs for companies but has also draw…
#         Hashtags: []
#         Name: DC
#         Username: DemetriusDC23
#         User Description: #lovegirls #succeed #nevergiveup
#         Social Status: 2907 friends, 2995 followers, 22086 favorites
#         Location: United States
#         Geocode: None
#         Date: Sun Aug 25 00:39:25 +0000 2019
#
#
# Text: RT @claudiomkd: What's the Difference Between #ArtificialIntelligence, #MachineLearning, and #DeepLearning?
#  by mvc |
#
# Read more here: http…
#         Hashtags: [{'text': 'ArtificialIntelligence', 'indices': [46, 69]}, {'text': 'MachineLearning', 'indices': [71, 87]}, {'text': 'DeepLearning', 'indices': [93, 106]}]
#         Name: jayeshthakur
#         Username: jayeshmthakur
#         User Description: Husband, Father, Student, Security n00b. Interested in Cyber Security Research, Pen testing, RED Teaming, & Threat Hunting, Thoughts and Tweets are my own.
#         Social Status: 699 friends, 1495 followers, 1271 favorites
#         Location: ::1
#         Geocode: None
#         Date: Sun Aug 25 00:39:09 +0000 2019
#
#
# Text: Artificial intelligence and machine learning are the next frontiers for ETFs, says industry pro https://t.co/tkywDjEjtt
#         Hashtags: []
#         Name: The AI Magazine
#         Username: Magazine_AI
#         User Description: The Magazine all about Artificial Intelligence. Hosted by homeAI
#         Social Status: 22 friends, 371 followers, 4 favorites
#         Location: Online
#         Geocode: None
#         Date: Sun Aug 25 00:39:02 +0000 2019

# %%
# print the next 5 tweets
next_page = url + response.json()['search_metadata']['next_results']
tweets = requests.get(next_page, auth = oauth).json()['statuses']
for tweet in tweets:
    print(tweet_to_string(tweet).strip())
    print('\n')
# Out:
# Text: RT @IBMSystems: Artificial intelligence is transforming the way we communicate with each other. But can your infrastructure harness the ful…
#         Hashtags: []
#         Name: Shubham kumar singh
#         Username: Shubham59039315
#         User Description: Fan of #jai shree ram #mahadev
#         Social Status: 4 friends, 15 followers, 5 favorites
#         Location: Barauni begusarai Bihar, India
#         Geocode: None
#         Date: Sun Aug 25 00:38:36 +0000 2019
#
#
# Text: Artificial intelligence will have implications for policymakers in education, welfare and geopolitics https://t.co/iCmYbfp8Ft
#         Hashtags: []
#         Name: The Economist
#         Username: EconUS
#         User Description: Official tweets from The Economist's US correspondents
#         Social Status: 582 friends, 90503 followers, 1176 favorites
#         Location: Washington
#         Geocode: None
#         Date: Sun Aug 25 00:38:15 +0000 2019
#
#
# Text: RT @neuriot_tech: neurIOT helps farmers identify 8 different diseases in wheat crop using Artificial Intelligence and Deep Learning image r…
#         Hashtags: []
#         Name: jayeshthakur
#         Username: jayeshmthakur
#         User Description: Husband, Father, Student, Security n00b. Interested in Cyber Security Research, Pen testing, RED Teaming, & Threat Hunting, Thoughts and Tweets are my own.
#         Social Status: 699 friends, 1495 followers, 1271 favorites
#         Location: ::1
#         Geocode: None
#         Date: Sun Aug 25 00:37:37 +0000 2019
#
#
# Text: RT @SASsoftware: Our $1 billion #AI investment continues to see traction. SAS grew 4x faster than the overall AI market in 2018. https://t.…
#         Hashtags: [{'text': 'AI', 'indices': [32, 35]}]
#         Name: Dean Melnyk
#         Username: DeanMelnyk
#         User Description: Leader SAS Western Canada Team, Dad, Husband, Hockey Coach & Die Hard Habs Fan
#         Social Status: 827 friends, 415 followers, 697 favorites
#         Location: Calgary, AB Canada
#         Geocode: None
#         Date: Sun Aug 25 00:36:52 +0000 2019
#
#
# Text: RT @sciam: Will China overtake the U.S. in artificial intelligence research? The nation wants to make its AI industry dominant by 2030 http…
#         Hashtags: []
#         Name: Jesse James Jarmon
#         Username: JarmonJesse
#         User Description: I'm an Atheist, a self-proclaimed Compassionate Conservationist, reads sci articles, an advocate for non-native species that are overly-maligned.
#         Social Status: 52 friends, 36 followers, 2481 favorites
#         Location:
#         Geocode: None
#         Date: Sun Aug 25 00:36:25 +0000 2019

# %%
# compile tweets as dataframe
tweets_to_df(tweets)
# Out:
#                     id            user_name  user_screenname  \
# 0  1165423194678784001  Shubham kumar singh  Shubham59039315
# 1  1165423107361914880        The Economist           EconUS
# 2  1165422947122565123         jayeshthakur    jayeshmthakur
# 3  1165422756395008000          Dean Melnyk       DeanMelnyk
# 4  1165422644499554310   Jesse James Jarmon      JarmonJesse
#
#                                     user_description  user_friends  \
# 0                     Fan of #jai shree ram #mahadev             4
# 1  Official tweets from The Economist's US corres...           582
# 2  Husband, Father, Student, Security n00b. Inter...           699
# 3  Leader SAS Western Canada Team, Dad, Husband, ...           827
# 4  I'm an Atheist, a self-proclaimed Compassionat...            52
#
#    user_followers  user_favorites  retweets                            date  \
# 0              15               5       638  Sun Aug 25 00:38:36 +0000 2019
# 1           90503            1176         0  Sun Aug 25 00:38:15 +0000 2019
# 2            1495            1271         2  Sun Aug 25 00:37:37 +0000 2019
# 3             415             697        43  Sun Aug 25 00:36:52 +0000 2019
# 4              36            2481        63  Sun Aug 25 00:36:25 +0000 2019
#
#                          location geocode hashtags  \
# 0  Barauni begusarai Bihar, India    None      NaN
# 1                      Washington    None      NaN
# 2                             ::1    None      NaN
# 3              Calgary, AB Canada    None     [AI]
# 4                             NaN    None      NaN
#
#                                                tweet
# 0  RT @IBMSystems: Artificial intelligence is tra...
# 1  Artificial intelligence will have implications...
# 2  RT @neuriot_tech: neurIOT helps farmers identi...
# 3  RT @SASsoftware: Our $1 billion #AI investment...
# 4  RT @sciam: Will China overtake the U.S. in art...

# %%
tweets_to_df(tweets)['tweet'][0]
# Out:
# 'RT @IBMSystems: Artificial intelligence is transforming the way we communicate with each other. But can your infrastructure harness the ful…'

# %%
# setup API connection with Tweepy
consumer_key = credentials["TWITTER_CONSUMER_KEY"]
consumer_secret = credentials["TWITTER_CONSUMER_KEY_SECRET"]
access_token_key = credentials["TWITTER_ACCESS_TOKEN"]
access_token_secret = credentials["TWITTER_ACCESS_TOKEN_SECRET"]

auth = tweepy.OAuthHandler(consumer_key = consumer_key, consumer_secret = consumer_secret)
auth.set_access_token(access_token_key, access_token_secret)

api = tweepy.API(auth, retry_count = 1, retry_delay = 10, wait_on_rate_limit = True, 
                 wait_on_rate_limit_notify = True)

# %%
# pull Tweets using Tweepy and display Tweet text
for index, tweet in enumerate(tweepy.Cursor(api.search, **parameters).items(5)):
    print(str(index) + '. ' + tweet.text + '\n')
# Out:
# 0. RT @KirkDBorne: The Black Box — Explainable Artificial Intelligence #XAI and the Limits of Human Deliberative Processes: https://t.co/VYs43…
#
# 1. RT @nordicinst: Scientist to Hollywood: Artificial Intelligence Doesn't Work the Way You Think it Does. #aiethics #MachineLearning #aiforgo…
#
# 2. RT @USATODAY: The increasing prevalence of Artificial Intelligence has boosted efficiency and reduced costs for companies but has also draw…
#
# 3. RT @claudiomkd: What's the Difference Between #ArtificialIntelligence, #MachineLearning, and #DeepLearning?
#  by mvc |
#
# Read more here: http…
#
# 4. Artificial intelligence and machine learning are the next frontiers for ETFs, says industry pro https://t.co/tkywDjEjtt

# %%
# make df from Tweepy tweets
cursor = tweepy.Cursor(api.search, **parameters).items(5)
tweets = [tweet._json for tweet in cursor]
tweet_df = pd.DataFrame(tweets)
tweet_df
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Sun Aug 25 00:40:33 +0000 2019
# 1         None        None  Sun Aug 25 00:40:04 +0000 2019
# 2         None        None  Sun Aug 25 00:39:25 +0000 2019
# 3         None        None  Sun Aug 25 00:39:09 +0000 2019
# 4         None        None  Sun Aug 25 00:39:02 +0000 2019
#
#                                             entities  favorite_count  \
# 0  {'hashtags': [{'text': 'XAI', 'indices': [68, ...               0
# 1  {'hashtags': [{'text': 'aiethics', 'indices': ...               0
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 3  {'hashtags': [{'text': 'ArtificialIntelligence...               0
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...               0
#
#    favorited   geo                   id               id_str  \
# 0      False  None  1165423683567050753  1165423683567050753
# 1      False  None  1165423561701380096  1165423561701380096
# 2      False  None  1165423399046397952  1165423399046397952
# 3      False  None  1165423333808070657  1165423333808070657
# 4      False  None  1165423301646266368  1165423301646266368
#
#   in_reply_to_screen_name  ...  \
# 0                    None  ...
# 1                    None  ...
# 2                    None  ...
# 3                    None  ...
# 4                    None  ...
#
#                                             metadata place possibly_sensitive  \
# 0  {'iso_language_code': 'en', 'result_type': 're...  None                NaN
# 1  {'iso_language_code': 'en', 'result_type': 're...  None                NaN
# 2  {'iso_language_code': 'en', 'result_type': 're...  None                NaN
# 3  {'iso_language_code': 'en', 'result_type': 're...  None                NaN
# 4  {'iso_language_code': 'en', 'result_type': 're...  None              False
#
#   retweet_count  retweeted                                   retweeted_status  \
# 0             6      False  {'created_at': 'Sat Aug 24 23:49:00 +0000 2019...
# 1             8      False  {'created_at': 'Sat Aug 24 16:10:26 +0000 2019...
# 2            19      False  {'created_at': 'Fri Aug 23 22:03:00 +0000 2019...
# 3             4      False  {'created_at': 'Sat Aug 24 21:11:42 +0000 2019...
# 4             0      False                                                NaN
#
#                                               source  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="https://twitter.bot" rel="nofollow">j...
# 4  <a href="https://dlvrit.com/" rel="nofollow">d...
#
#                                                 text truncated  \
# 0  RT @KirkDBorne: The Black Box — Explainable Ar...     False
# 1  RT @nordicinst: Scientist to Hollywood: Artifi...     False
# 2  RT @USATODAY: The increasing prevalence of Art...     False
# 3  RT @claudiomkd: What's the Difference Between ...     False
# 4  Artificial intelligence and machine learning a...     False
#
#                                                 user
# 0  {'id': 1364473266, 'id_str': '1364473266', 'na...
# 1  {'id': 1165345386019479552, 'id_str': '1165345...
# 2  {'id': 2314020889, 'id_str': '2314020889', 'na...
# 3  {'id': 190097582, 'id_str': '190097582', 'name...
# 4  {'id': 3689058808, 'id_str': '3689058808', 'na...
#
# [5 rows x 26 columns]

# %%
# Tweepy does not appear to support the Premium APIs - need TwitterAPI for older tweets
api = TwitterAPI(consumer_key, consumer_secret, access_token_key, access_token_secret)

# %%
# test query of Standard API (note order of terms in first argument)
r = api.request('search/tweets',
                {'q': "'Artificial Intelligence'",
                 'lang': 'en', 
                 'count': 1, 
                 'tweet_mode': 'extended'})
for tweet in r:
    pprint(tweet)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Aug 24 20:18:31 +0000 2019',
#  'display_text_range': [0, 116],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/themarkosmers/…',
#                         'expanded_url': 'https://twitter.com/themarkosmers/status/1165030284313731073',
#                         'indices': [117, 140],
#                         'url': 'https://t.co/VZYL80gaia'}],
#               'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': 'Point proven: artificial intelligence and self-driving cars are '
#               'safer than aggressive, passive aggressive LA drivers '
#               'https://t.co/VZYL80gaia',
#  'geo': None,
#  'id': 1165357739331031040,
#  'id_str': '1165357739331031040',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': True,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': {'attributes': {},
#            'bounding_box': {'coordinates': [[[-118.668404, 33.704538],
#                                              [-118.155409, 33.704538],
#                                              [-118.155409, 34.337041],
#                                              [-118.668404, 34.337041]]],
#                             'type': 'Polygon'},
#            'contained_within': [],
#            'country': 'United States',
#            'country_code': 'US',
#            'full_name': 'Los Angeles, CA',
#            'id': '3b77caf94bfc81fe',
#            'name': 'Los Angeles',
#            'place_type': 'city',
#            'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json'},
#  'possibly_sensitive': False,
#  'quoted_status': {'contributors': None,
#                    'coordinates': None,
#                    'created_at': 'Fri Aug 23 22:37:19 +0000 2019',
#                    'display_text_range': [6, 216],
#                    'entities': {'hashtags': [],
#                                 'symbols': [],
#                                 'urls': [],
#                                 'user_mentions': [{'id': 16374678,
#                                                    'id_str': '16374678',
#                                                    'indices': [0, 5],
#                                                    'name': 'ABC7 Eyewitness '
#                                                            'News',
#                                                    'screen_name': 'ABC7'}]},
#                    'favorite_count': 4,
#                    'favorited': False,
#                    'full_text': '@ABC7 Total disregard for other drivers on '
#                                 'the freeway. I’d be tempted to get in front '
#                                 'of this car and hit the brakes, but I '
#                                 'wouldn’t because I have respect for cars and '
#                                 'drivers, unlike this (insert adjective) '
#                                 'person',
#                    'geo': None,
#                    'id': 1165030284313731073,
#                    'id_str': '1165030284313731073',
#                    'in_reply_to_screen_name': 'ABC7',
#                    'in_reply_to_status_id': 1164996461873864704,
#                    'in_reply_to_status_id_str': '1164996461873864704',
#                    'in_reply_to_user_id': 16374678,
#                    'in_reply_to_user_id_str': '16374678',
#                    'is_quote_status': False,
#                    'lang': 'en',
#                    'metadata': {'iso_language_code': 'en',
#                                 'result_type': 'recent'},
#                    'place': None,
#                    'retweet_count': 0,
#                    'retweeted': False,
#                    'source': '<a href="http://twitter.com/download/iphone" '
#                              'rel="nofollow">Twitter for iPhone</a>',
#                    'truncated': False,
#                    'user': {'contributors_enabled': False,
#                             'created_at': 'Fri Feb 03 23:33:08 +0000 2012',
#                             'default_profile': True,
#                             'default_profile_image': False,
#                             'description': '#SusanGKomen #Cars #Trucks #SUVs '
#                                            '#Marketing  #DigitalMedia #Porsche '
#                                            '#Cycling #NashvillePredators '
#                                            '#GoNavy @AutoNation @DDB_Worldwide '
#                                            '@CampbellEwald',
#                             'entities': {'description': {'urls': []},
#                                          'url': {'urls': [{'display_url': 'autonation.com',
#                                                            'expanded_url': 'http://autonation.com',
#                                                            'indices': [0, 23],
#                                                            'url': 'https://t.co/7rJPvGwqoz'}]}},
#                             'favourites_count': 1351,
#                             'follow_request_sent': False,
#                             'followers_count': 271,
#                             'following': False,
#                             'friends_count': 404,
#                             'geo_enabled': True,
#                             'has_extended_profile': False,
#                             'id': 482478176,
#                             'id_str': '482478176',
#                             'is_translation_enabled': False,
#                             'is_translator': False,
#                             'lang': None,
#                             'listed_count': 52,
#                             'location': 'Orange County California',
#                             'name': 'Mark Osmers',
#                             'notifications': False,
#                             'profile_background_color': 'C0DEED',
#                             'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                             'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                             'profile_background_tile': False,
#                             'profile_banner_url': 'https://pbs.twimg.com/profile_banners/482478176/1479481367',
#                             'profile_image_url': 'http://pbs.twimg.com/profile_images/942119245093187584/MApMGP4r_normal.jpg',
#                             'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942119245093187584/MApMGP4r_normal.jpg',
#                             'profile_link_color': '1DA1F2',
#                             'profile_sidebar_border_color': 'C0DEED',
#                             'profile_sidebar_fill_color': 'DDEEF6',
#                             'profile_text_color': '333333',
#                             'profile_use_background_image': True,
#                             'protected': False,
#                             'screen_name': 'TheMarkOsmers',
#                             'statuses_count': 2640,
#                             'time_zone': None,
#                             'translator_type': 'none',
#                             'url': 'https://t.co/7rJPvGwqoz',
#                             'utc_offset': None,
#                             'verified': False}},
#  'quoted_status_id': 1165030284313731073,
#  'quoted_status_id_str': '1165030284313731073',
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Wed Dec 21 07:14:49 +0000 2011',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': '||Dream big|| Kinesiology.',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 40027,
#           'follow_request_sent': False,
#           'followers_count': 549,
#           'following': False,
#           'friends_count': 239,
#           'geo_enabled': True,
#           'has_extended_profile': True,
#           'id': 442561097,
#           'id_str': '442561097',
#           'is_translation_enabled': True,
#           'is_translator': False,
#           'lang': None,
#           'listed_count': 4,
#           'location': '',
#           'name': 'Aurora',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/442561097/1468636883',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/909865824491470848/skPNF9rr_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/909865824491470848/skPNF9rr_normal.jpg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'aurora_ob',
#           'statuses_count': 16589,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}

# %%
# in order to use the '30day' and 'fullarchive' (all years) Twitter Premium APIs, must first 
# set up 'development environments' associated with the app (https://developer.twitter.com/en/dashboard)
# see setup_twitter_instructions.md file linked earlier

# test query of '30day' Premium API
r = api.request('tweets/search/30day/:development',
                    params = 
                        {'query': "Artificial Intelligence",
                         'fromDate': '201908010000',
                         'toDate': '201908150000',
                         'maxResults': 10}
                   )
tweets = r.json()
pprint(tweets)
# Out:
# {'next': 'eyJhdXRoZW50aWNpdHkiOiI4YTRhMmNlOTFkNWMyMTRmOTZkMDQ0Mzk4NDBkNmM0MDU1MWNmMTdkZjdhNDlhMTI0ZDdiYWNjYTdkNTA3NDAwIiwiZnJvbURhdGUiOiIyMDE5MDgwMTAwMDAiLCJ0b0RhdGUiOiIyMDE5MDgxNTAwMDAiLCJuZXh0IjoiMjAxOTA4MTUwMDAwMDAtMTE2MTc4ODY3MjA4MzAzNDExNC0wIn0=',
#  'requestParameters': {'fromDate': '201908010000',
#                        'maxResults': 10,
#                        'toDate': '201908150000'},
#  'results': [{'contributors': None,
#               'coordinates': None,
#               'created_at': 'Wed Aug 14 23:59:50 +0000 2019',
#               'entities': {'hashtags': [],
#                            'symbols': [],
#                            'urls': [],
#                            'user_mentions': [{'id': 879548970082721792,
#                                               'id_str': '879548970082721792',
#                                               'indices': [3, 18],
#                                               'name': 'Rising serpent',
#                                               'screen_name': 'rising_serpent'}]},
#               'favorite_count': 0,
#               'favorited': False,
#               'filter_level': 'low',
#               'geo': None,
#               'id': 1161789559715196928,
#               'id_str': '1161789559715196928',
#               'in_reply_to_screen_name': None,
#               'in_reply_to_status_id': None,
#               'in_reply_to_status_id_str': None,
#               'in_reply_to_user_id': None,
#               'in_reply_to_user_id_str': None,
#               'is_quote_status': False,
#               'lang': 'en',
#               'matching_rules': [{'tag': None}],
#               'place': None,
#               'quote_count': 0,
#               'reply_count': 0,
#               'retweet_count': 0,
#               'retweeted': False,
#               'retweeted_status': {'contributors': None,
#                                    'coordinates': None,
#                                    'created_at': 'Wed Aug 14 17:59:17 +0000 '
#                                                  '2019',
#                                    'entities': {'hashtags': [],
#                                                 'symbols': [],
#                                                 'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                                           'expanded_url': 'https://twitter.com/i/web/status/1161698821702918145',
#                                                           'indices': [116, 139],
#                                                           'url': 'https://t.co/iZGhphMGRR'}],
#                                                 'user_mentions': []},
#                                    'extended_tweet': {'display_text_range': [0,
#                                                                              271],
#                                                       'entities': {'hashtags': [],
#                                                                    'symbols': [],
#                                                                    'urls': [],
#                                                                    'user_mentions': []},
#                                                       'full_text': 'Once you '
#                                                                    'combine '
#                                                                    'this '
#                                                                    'gigantic '
#                                                                    'amorphous '
#                                                                    'mass of '
#                                                                    'the human '
#                                                                    'gene code '
#                                                                    'with '
#                                                                    'artificial '
#                                                                    'intelligence '
#                                                                    'programming, '
#                                                                    'the '
#                                                                    'results '
#                                                                    'are far '
#                                                                    'beyond the '
#                                                                    'capacity '
#                                                                    'of my '
#                                                                    'meager '
#                                                                    'imagination.\n'
#                                                                    "I've "
#                                                                    'ranted '
#                                                                    'enough. '
#                                                                    'Gotta go '
#                                                                    'earn a '
#                                                                    'living so '
#                                                                    'that the '
#                                                                    'government '
#                                                                    'can give '
#                                                                    'my money '
#                                                                    'away.\n'
#                                                                    '-Fin'},
#                                    'favorite_count': 207,
#                                    'favorited': False,
#                                    'filter_level': 'low',
#                                    'geo': None,
#                                    'id': 1161698821702918145,
#                                    'id_str': '1161698821702918145',
#                                    'in_reply_to_screen_name': 'rising_serpent',
#                                    'in_reply_to_status_id': 1161698243815907333,
#                                    'in_reply_to_status_id_str': '1161698243815907333',
#                                    'in_reply_to_user_id': 879548970082721792,
#                                    'in_reply_to_user_id_str': '879548970082721792',
#                                    'is_quote_status': False,
#                                    'lang': 'en',
#                                    'place': None,
#                                    'quote_count': 2,
#                                    'reply_count': 9,
#                                    'retweet_count': 70,
#                                    'retweeted': False,
#                                    'source': '<a '
#                                              'href="http://twitter.com/download/android" '
#                                              'rel="nofollow">Twitter for '
#                                              'Android</a>',
#                                    'text': 'Once you combine this gigantic '
#                                            'amorphous mass of the human gene '
#                                            'code with artificial intelligence '
#                                            'programming, the… '
#                                            'https://t.co/iZGhphMGRR',
#                                    'truncated': True,
#                                    'user': {'contributors_enabled': False,
#                                             'created_at': 'Tue Jun 27 03:56:30 '
#                                                           '+0000 2017',
#                                             'default_profile': True,
#                                             'default_profile_image': False,
#                                             'description': 'les lèvres de la '
#                                                            'sagesse sont '
#                                                            'scellées, sauf aux '
#                                                            'oreilles de la '
#                                                            'compréhension',
#                                             'favourites_count': 4225,
#                                             'follow_request_sent': None,
#                                             'followers_count': 54280,
#                                             'following': None,
#                                             'friends_count': 3375,
#                                             'geo_enabled': False,
#                                             'id': 879548970082721792,
#                                             'id_str': '879548970082721792',
#                                             'is_translator': False,
#                                             'lang': None,
#                                             'listed_count': 420,
#                                             'location': "Closer than you'd "
#                                                         'imagine',
#                                             'name': 'Rising serpent',
#                                             'notifications': None,
#                                             'profile_background_color': 'F5F8FA',
#                                             'profile_background_image_url': '',
#                                             'profile_background_image_url_https': '',
#                                             'profile_background_tile': False,
#                                             'profile_banner_url': 'https://pbs.twimg.com/profile_banners/879548970082721792/1498922980',
#                                             'profile_image_url': 'http://pbs.twimg.com/profile_images/972707144762929152/ZC5wgh4k_normal.jpg',
#                                             'profile_image_url_https': 'https://pbs.twimg.com/profile_images/972707144762929152/ZC5wgh4k_normal.jpg',
#                                             'profile_link_color': '1DA1F2',
#                                             'profile_sidebar_border_color': 'C0DEED',
#                                             'profile_sidebar_fill_color': 'DDEEF6',
#                                             'profile_text_color': '333333',
#                                             'profile_use_background_image': True,
#                                             'protected': False,
#                                             'screen_name': 'rising_serpent',
#                                             'statuses_count': 41068,
#                                             'time_zone': None,
#                                             'translator_type': 'none',
#                                             'url': 'http://serpentrising.com',
#                                             'utc_offset': None,
#                                             'verified': False}},
#               'source': '<a href="https://mobile.twitter.com" '
#                         'rel="nofollow">Twitter Web App</a>',
#               'text': 'RT @rising_serpent: Once you combine this gigantic '
#                       'amorphous mass of the human gene code with artificial '
#                       'intelligence programming, the resu…',
#               'truncated': False,
#               'user': {'contributors_enabled': False,
#                        'created_at': 'Thu May 18 15:19:19 +0000 2017',
#                        'default_profile': False,
#                        'default_profile_image': False,
#                        'description': '"Shoot, if you must, this old gray head '
#                                       'But spare your country\'s flag" she '
#                                       'said. --- John Greenleaf Whittier\n'
#                                       'I study A Course in Miracles (ACIM). '
#                                       '#MAGA',
#                        'favourites_count': 52445,
#                        'follow_request_sent': None,
#                        'followers_count': 937,
#                        'following': None,
#                        'friends_count': 1191,
#                        'geo_enabled': False,
#                        'id': 865225293841158145,
#                        'id_str': '865225293841158145',
#                        'is_translator': False,
#                        'lang': None,
#                        'listed_count': 1,
#                        'location': None,
#                        'name': 'Barbara Frietchie',
#                        'notifications': None,
#                        'profile_background_color': '000000',
#                        'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                        'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                        'profile_background_tile': False,
#                        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/865225293841158145/1519426720',
#                        'profile_image_url': 'http://pbs.twimg.com/profile_images/967170725135073280/YT9sOwem_normal.jpg',
#                        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/967170725135073280/YT9sOwem_normal.jpg',
#                        'profile_link_color': '91D2FA',
#                        'profile_sidebar_border_color': '000000',
#                        'profile_sidebar_fill_color': '000000',
#                        'profile_text_color': '000000',
#                        'profile_use_background_image': False,
#                        'protected': False,
#                        'screen_name': 'Barbaren7',
#                        'statuses_count': 42071,
#                        'time_zone': None,
#                        'translator_type': 'none',
#                        'url': None,
#                        'utc_offset': None,
#                        'verified': False}},
#              {'contributors': None,
#               'coordinates': None,
#               'created_at': 'Wed Aug 14 23:59:28 +0000 2019',
#               'entities': {'hashtags': [],
#                            'symbols': [],
#                            'urls': [],
#                            'user_mentions': [{'id': 848833596,
#                                               'id_str': '848833596',
#                                               'indices': [3, 17],
#                                               'name': 'Domenico Calia',
#                                               'screen_name': 'CaliaDomenico'}]},
#               'favorite_count': 0,
#               'favorited': False,
#               'filter_level': 'low',
#               'geo': None,
#               'id': 1161789466148855818,
#               'id_str': '1161789466148855818',
#               'in_reply_to_screen_name': None,
#               'in_reply_to_status_id': None,
#               'in_reply_to_status_id_str': None,
#               'in_reply_to_user_id': None,
#               'in_reply_to_user_id_str': None,
#               'is_quote_status': False,
#               'lang': 'en',
#               'matching_rules': [{'tag': None}],
#               'place': None,
#               'quote_count': 0,
#               'reply_count': 0,
#               'retweet_count': 0,
#               'retweeted': False,
#               'retweeted_status': {'contributors': None,
#                                    'coordinates': None,
#                                    'created_at': 'Wed Aug 14 08:16:02 +0000 '
#                                                  '2019',
#                                    'display_text_range': [0, 140],
#                                    'entities': {'hashtags': [],
#                                                 'symbols': [],
#                                                 'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                                           'expanded_url': 'https://twitter.com/i/web/status/1161552045146595335',
#                                                           'indices': [117, 140],
#                                                           'url': 'https://t.co/eurRoYZ8tO'}],
#                                                 'user_mentions': []},
#                                    'extended_tweet': {'display_text_range': [0,
#                                                                              185],
#                                                       'entities': {'hashtags': [],
#                                                                    'media': [{'display_url': 'pic.twitter.com/tGBnmn8Z7g',
#                                                                               'expanded_url': 'https://twitter.com/CaliaDomenico/status/1161552045146595335/photo/1',
#                                                                               'id': 1161551970664161280,
#                                                                               'id_str': '1161551970664161280',
#                                                                               'indices': [186,
#                                                                                           209],
#                                                                               'media_url': 'http://pbs.twimg.com/tweet_video_thumb/EB6pXPeXoAAf1l1.jpg',
#                                                                               'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/EB6pXPeXoAAf1l1.jpg',
#                                                                               'sizes': {'large': {'h': 270,
#                                                                                                   'resize': 'fit',
#                                                                                                   'w': 480},
#                                                                                         'medium': {'h': 270,
#                                                                                                    'resize': 'fit',
#                                                                                                    'w': 480},
#                                                                                         'small': {'h': 270,
#                                                                                                   'resize': 'fit',
#                                                                                                   'w': 480},
#                                                                                         'thumb': {'h': 150,
#                                                                                                   'resize': 'crop',
#                                                                                                   'w': 150}},
#                                                                               'type': 'animated_gif',
#                                                                               'url': 'https://t.co/tGBnmn8Z7g',
#                                                                               'video_info': {'aspect_ratio': [16,
#                                                                                                               9],
#                                                                                              'variants': [{'bitrate': 0,
#                                                                                                            'content_type': 'video/mp4',
#                                                                                                            'url': 'https://video.twimg.com/tweet_video/EB6pXPeXoAAf1l1.mp4'}]}}],
#                                                                    'symbols': [],
#                                                                    'urls': [{'display_url': 'space.com/fast-radio-bur…',
#                                                                              'expanded_url': 'https://www.space.com/fast-radio-bursts-australia-artificial-intelligence.html',
#                                                                              'indices': [162,
#                                                                                          185],
#                                                                              'url': 'https://t.co/VDXgB0bjkq'}],
#                                                                    'user_mentions': []},
#                                                       'extended_entities': {'media': [{'display_url': 'pic.twitter.com/tGBnmn8Z7g',
#                                                                                        'expanded_url': 'https://twitter.com/CaliaDomenico/status/1161552045146595335/photo/1',
#                                                                                        'id': 1161551970664161280,
#                                                                                        'id_str': '1161551970664161280',
#                                                                                        'indices': [186,
#                                                                                                    209],
#                                                                                        'media_url': 'http://pbs.twimg.com/tweet_video_thumb/EB6pXPeXoAAf1l1.jpg',
#                                                                                        'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/EB6pXPeXoAAf1l1.jpg',
#                                                                                        'sizes': {'large': {'h': 270,
#                                                                                                            'resize': 'fit',
#                                                                                                            'w': 480},
#                                                                                                  'medium': {'h': 270,
#                                                                                                             'resize': 'fit',
#                                                                                                             'w': 480},
#                                                                                                  'small': {'h': 270,
#                                                                                                            'resize': 'fit',
#                                                                                                            'w': 480},
#                                                                                                  'thumb': {'h': 150,
#                                                                                                            'resize': 'crop',
#                                                                                                            'w': 150}},
#                                                                                        'type': 'animated_gif',
#                                                                                        'url': 'https://t.co/tGBnmn8Z7g',
#                                                                                        'video_info': {'aspect_ratio': [16,
#                                                                                                                        9],
#                                                                                                       'variants': [{'bitrate': 0,
#                                                                                                                     'content_type': 'video/mp4',
#                                                                                                                     'url': 'https://video.twimg.com/tweet_video/EB6pXPeXoAAf1l1.mp4'}]}}]},
#                                                       'full_text': 'An '
#                                                                    'animation '
#                                                                    'shows the '
#                                                                    'random '
#                                                                    'appearance '
#                                                                    'of fast '
#                                                                    'radio '
#                                                                    'bursts '
#                                                                    '(FRBs) '
#                                                                    'across the '
#                                                                    'sky. '
#                                                                    'Astronomers '
#                                                                    'have '
#                                                                    'discovered '
#                                                                    'about 85 '
#                                                                    'since '
#                                                                    '2007, and '
#                                                                    'pinpointed '
#                                                                    'two of '
#                                                                    'them.\n'
#                                                                    'https://t.co/VDXgB0bjkq '
#                                                                    'https://t.co/tGBnmn8Z7g'},
#                                    'favorite_count': 41,
#                                    'favorited': False,
#                                    'filter_level': 'low',
#                                    'geo': None,
#                                    'id': 1161552045146595335,
#                                    'id_str': '1161552045146595335',
#                                    'in_reply_to_screen_name': None,
#                                    'in_reply_to_status_id': None,
#                                    'in_reply_to_status_id_str': None,
#                                    'in_reply_to_user_id': None,
#                                    'in_reply_to_user_id_str': None,
#                                    'is_quote_status': False,
#                                    'lang': 'en',
#                                    'place': None,
#                                    'possibly_sensitive': False,
#                                    'quote_count': 0,
#                                    'reply_count': 0,
#                                    'retweet_count': 15,
#                                    'retweeted': False,
#                                    'source': '<a '
#                                              'href="http://twitter.com/download/iphone" '
#                                              'rel="nofollow">Twitter for '
#                                              'iPhone</a>',
#                                    'text': 'An animation shows the random '
#                                            'appearance of fast radio bursts '
#                                            '(FRBs) across the sky. Astronomers '
#                                            'have discovered ab… '
#                                            'https://t.co/eurRoYZ8tO',
#                                    'truncated': True,
#                                    'user': {'contributors_enabled': False,
#                                             'created_at': 'Thu Sep 27 07:40:42 '
#                                                           '+0000 2012',
#                                             'default_profile': True,
#                                             'default_profile_image': False,
#                                             'description': None,
#                                             'favourites_count': 25825,
#                                             'follow_request_sent': None,
#                                             'followers_count': 14240,
#                                             'following': None,
#                                             'friends_count': 826,
#                                             'geo_enabled': True,
#                                             'id': 848833596,
#                                             'id_str': '848833596',
#                                             'is_translator': False,
#                                             'lang': None,
#                                             'listed_count': 293,
#                                             'location': None,
#                                             'name': 'Domenico Calia',
#                                             'notifications': None,
#                                             'profile_background_color': 'C0DEED',
#                                             'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                             'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                             'profile_background_tile': False,
#                                             'profile_banner_url': 'https://pbs.twimg.com/profile_banners/848833596/1556177474',
#                                             'profile_image_url': 'http://pbs.twimg.com/profile_images/754629763499716608/-JS8bx9I_normal.jpg',
#                                             'profile_image_url_https': 'https://pbs.twimg.com/profile_images/754629763499716608/-JS8bx9I_normal.jpg',
#                                             'profile_link_color': '1DA1F2',
#                                             'profile_sidebar_border_color': 'C0DEED',
#                                             'profile_sidebar_fill_color': 'DDEEF6',
#                                             'profile_text_color': '333333',
#                                             'profile_use_background_image': True,
#                                             'protected': False,
#                                             'screen_name': 'CaliaDomenico',
#                                             'statuses_count': 46241,
#                                             'time_zone': None,
#                                             'translator_type': 'none',
#                                             'url': None,
#                                             'utc_offset': None,
#                                             'verified': False}},
#               'source': '<a href="http://twitter.com/download/iphone" '
#                         'rel="nofollow">Twitter for iPhone</a>',
#               'text': 'RT @CaliaDomenico: An animation shows the random '
#                       'appearance of fast radio bursts (FRBs) across the sky. '
#                       'Astronomers have discovered about 8…',
#               'truncated': False,
#               'user': {'contributors_enabled': False,
#                        'created_at': 'Tue Jan 30 11:23:21 +0000 2018',
#                        'default_profile': True,
#                        'default_profile_image': False,
#                        'description': None,
#                        'favourites_count': 1005,
#                        'follow_request_sent': None,
#                        'followers_count': 2,
#                        'following': None,
#                        'friends_count': 145,
#                        'geo_enabled': False,
#                        'id': 958299591539032064,
#                        'id_str': '958299591539032064',
#                        'is_translator': False,
#                        'lang': None,
#                        'listed_count': 0,
#                        'location': None,
#                        'name': 'dmi',
#                        'notifications': None,
#                        'profile_background_color': 'F5F8FA',
#                        'profile_background_image_url': '',
#                        'profile_background_image_url_https': '',
#                        'profile_background_tile': False,
#                        'profile_image_url': 'http://pbs.twimg.com/profile_images/993274597113061381/x3oLM_h__normal.jpg',
#                        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/993274597113061381/x3oLM_h__normal.jpg',
#                        'profile_link_color': '1DA1F2',
#                        'profile_sidebar_border_color': 'C0DEED',
#                        'profile_sidebar_fill_color': 'DDEEF6',
#                        'profile_text_color': '333333',
#                        'profile_use_background_image': True,
#                        'protected': False,
#                        'screen_name': 'dmitsag',
#                        'statuses_count': 657,
#                        'time_zone': None,
#                        'translator_type': 'none',
#                        'url': None,
#                        'utc_offset': None,
#                        'verified': False}},
#              {'contributors': None,
#               'coordinates': None,
#               'created_at': 'Wed Aug 14 23:58:56 +0000 2019',
#               'entities': {'hashtags': [],
#                            'symbols': [],
#                            'urls': [],
#                            'user_mentions': [{'id': 755644327217496064,
#                                               'id_str': '755644327217496064',
#                                               'indices': [3, 15],
#                                               'name': 'Emile Contal',
#                                               'screen_name': 'emilecontal'},
#                                              {'id': 1701540050,
#                                               'id_str': '1701540050',
#                                               'indices': [104, 119],
#                                               'name': 'Alexandre Robicquet',
#                                               'screen_name': 'AlexandreRbcqt'}]},
#               'favorite_count': 0,
#               'favorited': False,
#               'filter_level': 'low',
#               'geo': None,
#               'id': 1161789333462032398,
#               'id_str': '1161789333462032398',
#               'in_reply_to_screen_name': None,
#               'in_reply_to_status_id': None,
#               'in_reply_to_status_id_str': None,
#               'in_reply_to_user_id': None,
#               'in_reply_to_user_id_str': None,
#               'is_quote_status': False,
#               'lang': 'en',
#               'matching_rules': [{'tag': None}],
#               'place': None,
#               'quote_count': 0,
#               'reply_count': 0,
#               'retweet_count': 0,
#               'retweeted': False,
#               'retweeted_status': {'contributors': None,
#                                    'coordinates': None,
#                                    'created_at': 'Tue Aug 13 17:44:36 +0000 '
#                                                  '2019',
#                                    'entities': {'hashtags': [],
#                                                 'symbols': [],
#                                                 'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                                           'expanded_url': 'https://twitter.com/i/web/status/1161332740802797568',
#                                                           'indices': [117, 140],
#                                                           'url': 'https://t.co/Iu49fb1DfR'}],
#                                                 'user_mentions': [{'id': 1701540050,
#                                                                    'id_str': '1701540050',
#                                                                    'indices': [87,
#                                                                                102],
#                                                                    'name': 'Alexandre '
#                                                                            'Robicquet',
#                                                                    'screen_name': 'AlexandreRbcqt'}]},
#                                    'extended_tweet': {'display_text_range': [0,
#                                                                              151],
#                                                       'entities': {'hashtags': [],
#                                                                    'symbols': [],
#                                                                    'urls': [{'display_url': 'apple.news/APWG7OVWITUK1i…',
#                                                                              'expanded_url': 'https://apple.news/APWG7OVWITUK1iOuQ5JK6qw',
#                                                                              'indices': [128,
#                                                                                          151],
#                                                                              'url': 'https://t.co/jtLsu8IgRO'}],
#                                                                    'user_mentions': [{'id': 1701540050,
#                                                                                       'id_str': '1701540050',
#                                                                                       'indices': [87,
#                                                                                                   102],
#                                                                                       'name': 'Alexandre '
#                                                                                               'Robicquet',
#                                                                                       'screen_name': 'AlexandreRbcqt'}]},
#                                                       'full_text': 'How to '
#                                                                    'Begin '
#                                                                    'Learning '
#                                                                    'About '
#                                                                    'Artificial '
#                                                                    'Intelligence? '
#                                                                    'See the '
#                                                                    'response '
#                                                                    'of my '
#                                                                    'Co-Founder '
#                                                                    '@AlexandreRbcqt '
#                                                                    'published '
#                                                                    'on Apple '
#                                                                    'News! '
#                                                                    'https://t.co/jtLsu8IgRO'},
#                                    'favorite_count': 6,
#                                    'favorited': False,
#                                    'filter_level': 'low',
#                                    'geo': None,
#                                    'id': 1161332740802797568,
#                                    'id_str': '1161332740802797568',
#                                    'in_reply_to_screen_name': None,
#                                    'in_reply_to_status_id': None,
#                                    'in_reply_to_status_id_str': None,
#                                    'in_reply_to_user_id': None,
#                                    'in_reply_to_user_id_str': None,
#                                    'is_quote_status': False,
#                                    'lang': 'en',
#                                    'place': None,
#                                    'possibly_sensitive': False,
#                                    'quote_count': 0,
#                                    'reply_count': 0,
#                                    'retweet_count': 3,
#                                    'retweeted': False,
#                                    'source': '<a '
#                                              'href="https://mobile.twitter.com" '
#                                              'rel="nofollow">Twitter Web '
#                                              'App</a>',
#                                    'text': 'How to Begin Learning About '
#                                            'Artificial Intelligence? See the '
#                                            'response of my Co-Founder '
#                                            '@AlexandreRbcqt published on… '
#                                            'https://t.co/Iu49fb1DfR',
#                                    'truncated': True,
#                                    'user': {'contributors_enabled': False,
#                                             'created_at': 'Wed Jul 20 06:03:41 '
#                                                           '+0000 2016',
#                                             'default_profile': True,
#                                             'default_profile_image': False,
#                                             'description': 'Co-Founder of '
#                                                            '@Crossing_Minds',
#                                             'favourites_count': 137,
#                                             'follow_request_sent': None,
#                                             'followers_count': 83,
#                                             'following': None,
#                                             'friends_count': 87,
#                                             'geo_enabled': False,
#                                             'id': 755644327217496064,
#                                             'id_str': '755644327217496064',
#                                             'is_translator': False,
#                                             'lang': None,
#                                             'listed_count': 4,
#                                             'location': None,
#                                             'name': 'Emile Contal',
#                                             'notifications': None,
#                                             'profile_background_color': 'F5F8FA',
#                                             'profile_background_image_url': '',
#                                             'profile_background_image_url_https': '',
#                                             'profile_background_tile': False,
#                                             'profile_banner_url': 'https://pbs.twimg.com/profile_banners/755644327217496064/1553838493',
#                                             'profile_image_url': 'http://pbs.twimg.com/profile_images/973034032538697728/aknBW82T_normal.jpg',
#                                             'profile_image_url_https': 'https://pbs.twimg.com/profile_images/973034032538697728/aknBW82T_normal.jpg',
#                                             'profile_link_color': '1DA1F2',
#                                             'profile_sidebar_border_color': 'C0DEED',
#                                             'profile_sidebar_fill_color': 'DDEEF6',
#                                             'profile_text_color': '333333',
#                                             'profile_use_background_image': True,
#                                             'protected': False,
#                                             'screen_name': 'emilecontal',
#                                             'statuses_count': 85,
#                                             'time_zone': None,
#                                             'translator_type': 'none',
#                                             'url': None,
#                                             'utc_offset': None,
#                                             'verified': False}},
#               'source': '<a href="http://twitter.com/download/iphone" '
#                         'rel="nofollow">Twitter for iPhone</a>',
#               'text': 'RT @emilecontal: How to Begin Learning About Artificial '
#                       'Intelligence? See the response of my Co-Founder '
#                       '@AlexandreRbcqt published on Apple…',
#               'truncated': False,
#               'user': {'contributors_enabled': False,
#                        'created_at': 'Sat Apr 26 15:34:35 +0000 2008',
#                        'default_profile': False,
#                        'default_profile_image': False,
#                        'description': 'Loyal. Sales, @Yieldmo. Love @Patriots; '
#                                       'music (MGMT/Spiritual Advisor, '
#                                       '@jazminlabrie; MGMT, @Kivvy); coffee '
#                                       '(always double-cupped). Champion of my '
#                                       'family | SBB',
#                        'favourites_count': 173,
#                        'follow_request_sent': None,
#                        'followers_count': 4494,
#                        'following': None,
#                        'friends_count': 3822,
#                        'geo_enabled': True,
#                        'id': 14546690,
#                        'id_str': '14546690',
#                        'is_translator': False,
#                        'lang': None,
#                        'listed_count': 218,
#                        'location': 'A Christian in New York City',
#                        'name': 'John Exley',
#                        'notifications': None,
#                        'profile_background_color': '709397',
#                        'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif',
#                        'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif',
#                        'profile_background_tile': True,
#                        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14546690/1401662047',
#                        'profile_image_url': 'http://pbs.twimg.com/profile_images/1113865467817529344/AE9QoETt_normal.jpg',
#                        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1113865467817529344/AE9QoETt_normal.jpg',
#                        'profile_link_color': 'FF3300',
#                        'profile_sidebar_border_color': 'FFFFFF',
#                        'profile_sidebar_fill_color': 'A0C5C7',
#                        'profile_text_color': '333333',
#                        'profile_use_background_image': True,
#                        'protected': False,
#                        'screen_name': 'JohnExley',
#                        'statuses_count': 39317,
#                        'time_zone': None,
#                        'translator_type': 'none',
#                        'url': 'http://www.thelucidrealm.com/',
#                        'utc_offset': None,
#                        'verified': False}},
#              {'contributors': None,
#               'coordinates': None,
#               'created_at': 'Wed Aug 14 23:58:43 +0000 2019',
#               'entities': {'hashtags': [],
#                            'symbols': [],
#                            'urls': [],
#                            'user_mentions': [{'id': 807880205331300352,
#                                               'id_str': '807880205331300352',
#                                               'indices': [3, 11],
#                                               'name': 'DPA2018',
#                                               'screen_name': 'DPA2018'}]},
#               'favorite_count': 0,
#               'favorited': False,
#               'filter_level': 'low',
#               'geo': None,
#               'id': 1161789277484830720,
#               'id_str': '1161789277484830720',
#               'in_reply_to_screen_name': None,
#               'in_reply_to_status_id': None,
#               'in_reply_to_status_id_str': None,
#               'in_reply_to_user_id': None,
# ...
#               'truncated': True,
#               'user': {'contributors_enabled': False,
#                        'created_at': 'Mon Dec 05 01:49:34 +0000 2016',
#                        'default_profile': True,
#                        'default_profile_image': False,
#                        'description': 'Get the latest, trending news hot off '
#                                       'the press, blogs and original content '
#                                       'offering coverage of US politics, '
#                                       'entertainment, world news,',
#                        'favourites_count': 1,
#                        'follow_request_sent': None,
#                        'followers_count': 173,
#                        'following': None,
#                        'friends_count': 35,
#                        'geo_enabled': False,
#                        'id': 805589900963647488,
#                        'id_str': '805589900963647488',
#                        'is_translator': False,
#                        'lang': None,
#                        'listed_count': 4,
#                        'location': 'California, USA',
#                        'name': 'Trending Press News',
#                        'notifications': None,
#                        'profile_background_color': 'F5F8FA',
#                        'profile_background_image_url': '',
#                        'profile_background_image_url_https': '',
#                        'profile_background_tile': False,
#                        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805589900963647488/1480903022',
#                        'profile_image_url': 'http://pbs.twimg.com/profile_images/805591302733590528/y3s-3jPs_normal.jpg',
#                        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805591302733590528/y3s-3jPs_normal.jpg',
#                        'profile_link_color': '1DA1F2',
#                        'profile_sidebar_border_color': 'C0DEED',
#                        'profile_sidebar_fill_color': 'DDEEF6',
#                        'profile_text_color': '333333',
#                        'profile_use_background_image': True,
#                        'protected': False,
#                        'screen_name': 'trendingpress1',
#                        'statuses_count': 158130,
#                        'time_zone': None,
#                        'translator_type': 'none',
#                        'url': None,
#                        'utc_offset': None,
#                        'verified': False}},
#              {'contributors': None,
#               'coordinates': None,
#               'created_at': 'Wed Aug 14 23:56:19 +0000 2019',
#               'entities': {'hashtags': [],
#                            'symbols': [],
#                            'urls': [],
#                            'user_mentions': [{'id': 110922804,
#                                               'id_str': '110922804',
#                                               'indices': [3, 19],
#                                               'name': 'Asia Times',
#                                               'screen_name': 'asiatimesonline'}]},
#               'favorite_count': 0,
#               'favorited': False,
#               'filter_level': 'low',
#               'geo': None,
#               'id': 1161788672083034114,
#               'id_str': '1161788672083034114',
#               'in_reply_to_screen_name': None,
#               'in_reply_to_status_id': None,
#               'in_reply_to_status_id_str': None,
#               'in_reply_to_user_id': None,
#               'in_reply_to_user_id_str': None,
#               'is_quote_status': False,
#               'lang': 'en',
#               'matching_rules': [{'tag': None}],
#               'place': None,
#               'quote_count': 0,
#               'reply_count': 0,
#               'retweet_count': 0,
#               'retweeted': False,
#               'retweeted_status': {'contributors': None,
#                                    'coordinates': None,
#                                    'created_at': 'Wed Aug 14 19:05:03 +0000 '
#                                                  '2019',
#                                    'entities': {'hashtags': [],
#                                                 'symbols': [],
#                                                 'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                                           'expanded_url': 'https://twitter.com/i/web/status/1161715374439763968',
#                                                           'indices': [117, 140],
#                                                           'url': 'https://t.co/qnyoISOJwJ'}],
#                                                 'user_mentions': []},
#                                    'extended_tweet': {'display_text_range': [0,
#                                                                              197],
#                                                       'entities': {'hashtags': [{'indices': [159,
#                                                                                              165],
#                                                                                  'text': 'China'},
#                                                                                 {'indices': [166,
#                                                                                              173],
#                                                                                  'text': 'drones'}],
#                                                                    'symbols': [],
#                                                                    'urls': [{'display_url': 'asiatimes.com/2019/08/articl…',
#                                                                              'expanded_url': 'https://www.asiatimes.com/2019/08/article/can-chinas-fighter-drones-go-it-alone-experts-say-yes/',
#                                                                              'indices': [174,
#                                                                                          197],
#                                                                              'url': 'https://t.co/898XSx5fvP'}],
#                                                                    'user_mentions': []},
#                                                       'full_text': 'Chinese '
#                                                                    'military '
#                                                                    'experts '
#                                                                    'say that '
#                                                                    'integrated '
#                                                                    'artificial '
#                                                                    'intelligence '
#                                                                    '(AI) '
#                                                                    'drones '
#                                                                    'could fly '
#                                                                    'on their '
#                                                                    'own, '
#                                                                    'identify '
#                                                                    'potential '
#                                                                    'targets '
#                                                                    'and make '
#                                                                    'combat '
#                                                                    'decisions. '
#                                                                    '#China '
#                                                                    '#drones '
#                                                                    'https://t.co/898XSx5fvP'},
#                                    'favorite_count': 2,
#                                    'favorited': False,
#                                    'filter_level': 'low',
#                                    'geo': None,
#                                    'id': 1161715374439763968,
#                                    'id_str': '1161715374439763968',
#                                    'in_reply_to_screen_name': None,
#                                    'in_reply_to_status_id': None,
#                                    'in_reply_to_status_id_str': None,
#                                    'in_reply_to_user_id': None,
#                                    'in_reply_to_user_id_str': None,
#                                    'is_quote_status': False,
#                                    'lang': 'en',
#                                    'place': None,
#                                    'possibly_sensitive': False,
#                                    'quote_count': 0,
#                                    'reply_count': 0,
#                                    'retweet_count': 3,
#                                    'retweeted': False,
#                                    'source': '<a href="https://buffer.com" '
#                                              'rel="nofollow">Buffer</a>',
#                                    'text': 'Chinese military experts say that '
#                                            'integrated artificial intelligence '
#                                            '(AI) drones could fly on their '
#                                            'own, identify p… '
#                                            'https://t.co/qnyoISOJwJ',
#                                    'truncated': True,
#                                    'user': {'contributors_enabled': False,
#                                             'created_at': 'Wed Feb 03 06:22:43 '
#                                                           '+0000 2010',
#                                             'default_profile': False,
#                                             'default_profile_image': False,
#                                             'description': 'Fast, accurate '
#                                                            'news, commentary '
#                                                            'and analysis for '
#                                                            'Asia and the '
#                                                            'world.\n'
#                                                            'Read • Think • '
#                                                            'Know • Asia',
#                                             'favourites_count': 100,
#                                             'follow_request_sent': None,
#                                             'followers_count': 21877,
#                                             'following': None,
#                                             'friends_count': 547,
#                                             'geo_enabled': False,
#                                             'id': 110922804,
#                                             'id_str': '110922804',
#                                             'is_translator': False,
#                                             'lang': None,
#                                             'listed_count': 1119,
#                                             'location': 'Asia',
#                                             'name': 'Asia Times',
#                                             'notifications': None,
#                                             'profile_background_color': '000000',
#                                             'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#                                             'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#                                             'profile_background_tile': False,
#                                             'profile_banner_url': 'https://pbs.twimg.com/profile_banners/110922804/1475749676',
#                                             'profile_image_url': 'http://pbs.twimg.com/profile_images/783976339602800640/IRukaym2_normal.jpg',
#                                             'profile_image_url_https': 'https://pbs.twimg.com/profile_images/783976339602800640/IRukaym2_normal.jpg',
#                                             'profile_link_color': '1B95E0',
#                                             'profile_sidebar_border_color': '000000',
#                                             'profile_sidebar_fill_color': '000000',
#                                             'profile_text_color': '000000',
#                                             'profile_use_background_image': False,
#                                             'protected': False,
#                                             'screen_name': 'asiatimesonline',
#                                             'statuses_count': 38620,
#                                             'time_zone': None,
#                                             'translator_type': 'none',
#                                             'url': 'http://asiatimes.com',
#                                             'utc_offset': None,
#                                             'verified': False}},
#               'source': '<a href="http://twitter.com/download/android" '
#                         'rel="nofollow">Twitter for Android</a>',
#               'text': 'RT @asiatimesonline: Chinese military experts say that '
#                       'integrated artificial intelligence (AI) drones could '
#                       'fly on their own, identify pote…',
#               'truncated': False,
#               'user': {'contributors_enabled': False,
#                        'created_at': 'Wed May 04 18:30:30 +0000 2011',
#                        'default_profile': True,
#                        'default_profile_image': False,
#                        'description': 'Traveller Bonnie & Kawa Rider '
#                                       'Photographer Bird Watcher History buff',
#                        'favourites_count': 3099,
#                        'follow_request_sent': None,
#                        'followers_count': 79,
#                        'following': None,
#                        'friends_count': 74,
#                        'geo_enabled': False,
#                        'id': 293078019,
#                        'id_str': '293078019',
#                        'is_translator': False,
#                        'lang': None,
#                        'listed_count': 2,
#                        'location': None,
#                        'name': 'NP',
#                        'notifications': None,
#                        'profile_background_color': 'C0DEED',
#                        'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                        'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                        'profile_background_tile': False,
#                        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/293078019/1540976627',
#                        'profile_image_url': 'http://pbs.twimg.com/profile_images/1025552553033916418/g-tgtGlj_normal.jpg',
#                        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1025552553033916418/g-tgtGlj_normal.jpg',
#                        'profile_link_color': '1DA1F2',
#                        'profile_sidebar_border_color': 'C0DEED',
#                        'profile_sidebar_fill_color': 'DDEEF6',
#                        'profile_text_color': '333333',
#                        'profile_use_background_image': True,
#                        'protected': False,
#                        'screen_name': 'NarenNp',
#                        'statuses_count': 3615,
#                        'time_zone': None,
#                        'translator_type': 'none',
#                        'url': None,
#                        'utc_offset': None,
#                        'verified': False}}]}

# %%
tweets.keys()
# Out:
# dict_keys(['results', 'next', 'requestParameters'])

# %%
tweets['requestParameters']
# Out:
# {'maxResults': 10, 'fromDate': '201908010000', 'toDate': '201908150000'}

# %%
tweets['next']  # next key provided when additional pages available
# Out:
# 'eyJhdXRoZW50aWNpdHkiOiI4YTRhMmNlOTFkNWMyMTRmOTZkMDQ0Mzk4NDBkNmM0MDU1MWNmMTdkZjdhNDlhMTI0ZDdiYWNjYTdkNTA3NDAwIiwiZnJvbURhdGUiOiIyMDE5MDgwMTAwMDAiLCJ0b0RhdGUiOiIyMDE5MDgxNTAwMDAiLCJuZXh0IjoiMjAxOTA4MTUwMDAwMDAtMTE2MTc4ODY3MjA4MzAzNDExNC0wIn0='

# %%
for tweet in tweets['results']:
    print(tweet_to_string(tweet))
# Out:
#         Text: RT @rising_serpent: Once you combine this gigantic amorphous mass of the human gene code with artificial intelligence programming, the resu…
#         Hashtags: []
#         Name: Barbara Frietchie
#         Username: Barbaren7
#         User Description: "Shoot, if you must, this old gray head But spare your country's flag" she said. --- John Greenleaf Whittier
# I study A Course in Miracles (ACIM). #MAGA
#         Social Status: 1191 friends, 937 followers, 52445 favorites
#         Location: None
#         Geocode: None
#         Date: Wed Aug 14 23:59:50 +0000 2019
#
#
#         Text: RT @CaliaDomenico: An animation shows the random appearance of fast radio bursts (FRBs) across the sky. Astronomers have discovered about 8…
#         Hashtags: []
#         Name: dmi
#         Username: dmitsag
#         User Description: None
#         Social Status: 145 friends, 2 followers, 1005 favorites
#         Location: None
#         Geocode: None
#         Date: Wed Aug 14 23:59:28 +0000 2019
#
#
#         Text: RT @emilecontal: How to Begin Learning About Artificial Intelligence? See the response of my Co-Founder @AlexandreRbcqt published on Apple…
#         Hashtags: []
#         Name: John Exley
#         Username: JohnExley
#         User Description: Loyal. Sales, @Yieldmo. Love @Patriots; music (MGMT/Spiritual Advisor, @jazminlabrie; MGMT, @Kivvy); coffee (always double-cupped). Champion of my family | SBB
#         Social Status: 3822 friends, 4494 followers, 173 favorites
#         Location: A Christian in New York City
#         Geocode: None
#         Date: Wed Aug 14 23:58:56 +0000 2019
#
#
#         Text: RT @DPA2018: RT NelsonRemolina: The world would change positively not only with the Ethical development of artificial  intelligences, but w…
#         Hashtags: []
#         Name: Gabriela Ríos
#         Username: Griosrios98
#         User Description: Derecho
# Universidad de Los Andes
#         Social Status: 1000 friends, 1283 followers, 40 favorites
#         Location: None
#         Geocode: None
#         Date: Wed Aug 14 23:58:43 +0000 2019
#
#
#         Text: RT @UCLAJCCC: #UCLA researchers have developed a new artificial intelligence system to help radiologists improve their ability to diagnose…
#         Hashtags: [{'text': 'UCLA', 'indices': [14, 19]}]
#         Name: M = Money. B = Bitcoin. C = Capital
#         Username: mbchoe
#         User Description: Hoover. M Friedman. G Becker. T Sowell. W Williams. F Bastiat. R Epstein. G Gilder. D Irwin. D Ricardo. A Smith. Wealth of Nations.
#         Social Status: 247 friends, 3 followers, 277 favorites
#         Location: MALIBU
#         Geocode: None
#         Date: Wed Aug 14 23:58:38 +0000 2019
#
#
#         Text: RT @emilecontal: How to Begin Learning About Artificial Intelligence? See the response of my Co-Founder @AlexandreRbcqt published on Apple…
#         Hashtags: []
#         Name: Alexandre Robicquet
#         Username: AlexandreRbcqt
#         User Description: Co-Founder @crossing_minds / Stanford Research Assistant
#         Social Status: 87 friends, 634 followers, 455 favorites
#         Location: San Francisco, CA
#         Geocode: None
#         Date: Wed Aug 14 23:58:34 +0000 2019
#
#
#         Text: Not sure I want artificial intelligence to be built by the lowest bidder...
# @thespybrief https://t.co/HwfEND2Xvf
#         Hashtags: []
#         Name: Chey Cobb, cissp, lsmft, iirtplayn
#         Username: chey_cobb
#         User Description: Digital Security & Privacy Futurist // Cannabis Researcher // Writer // Consultant // I'd rather be sailing!
#         Social Status: 405 friends, 1666 followers, 20576 favorites
#         Location: UK
#         Geocode: None
#         Date: Wed Aug 14 23:57:47 +0000 2019
#
#
#         Text: This Video May Not Be Real - https://t.co/Apc82H9PRV -
#
# By Claire Wardle
# Video by Leah Varjacques and Taige Jensen… https://t.co/WGXN3EZmRk
#         Hashtags: []
#         Name: Trending Press News
#         Username: trendingpress1
#         User Description: Get the latest, trending news hot off the press, blogs and original content offering coverage of US politics, entertainment, world news,
#         Social Status: 35 friends, 173 followers, 1 favorites
#         Location: California, USA
#         Geocode: None
#         Date: Wed Aug 14 23:57:25 +0000 2019
#
#
#         Text: RT @asiatimesonline: Chinese military experts say that integrated artificial intelligence (AI) drones could fly on their own, identify pote…
#         Hashtags: []
#         Name: NP
#         Username: NarenNp
#         User Description: Traveller Bonnie & Kawa Rider Photographer Bird Watcher History buff
#         Social Status: 74 friends, 79 followers, 3099 favorites
#         Location: None
#         Geocode: None
#         Date: Wed Aug 14 23:56:19 +0000 2019

# %%
# to get full tweet text (Premium API requests truncate tweet text by default)
print(tweets['results'][0]['retweeted_status']['extended_tweet']['full_text'])
# Out:
# Once you combine this gigantic amorphous mass of the human gene code with artificial intelligence programming, the results are far beyond the capacity of my meager imagination.
# I've ranted enough. Gotta go earn a living so that the government can give my money away.
# -Fin

# %%
query = '("Artificial Intelligence") OR #ArtificialIntelligence OR #AI lang:en'

# test query of 30day Premium API
get_tweets_premium(api, 1, '30day', 'development', query = query, 
                   fromDate = '201908010000', toDate = '201908140000', 
                   maxResults = 10)
# Out:
# [{'created_at': 'Tue Aug 13 23:59:59 +0000 2019',
#   'id': 1161427210252836864,
#   'id_str': '1161427210252836864',
#   'text': 'RT @Paula_Piccard: This app helps the visually impaired identify surroundings\n#AI #ArtificialIntelligence #ML #ComputerVision #IoT #Tech\n\n@…',
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1003882296003481600,
#    'id_str': '1003882296003481600',
#    'name': 'Minmax',
#    'screen_name': 'Seasidesevn1',
#    'location': None,
#    'url': None,
#    'description': None,
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 7,
#    'friends_count': 26,
#    'listed_count': 2,
#    'favourites_count': 62,
#    'statuses_count': 245,
#    'created_at': 'Tue Jun 05 06:12:45 +0000 2018',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1013358003364487168/to1NuuEn_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1013358003364487168/to1NuuEn_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1003882296003481600/1545422417',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Aug 13 12:30:00 +0000 2019',
#    'id': 1161253568885809152,
#    'id_str': '1161253568885809152',
#    'text': 'This app helps the visually impaired identify surroundings\n#AI #ArtificialIntelligence #ML #ComputerVision #IoT… https://t.co/c56ivW7ZiG',
#    'display_text_range': [0, 140],
#    'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 291831562,
#     'id_str': '291831562',
#     'name': 'Paula Piccard 🇵🇷 🇺🇸',
#     'screen_name': 'Paula_Piccard',
#     'location': 'New York, USA',
#     'url': 'https://www.linkedin.com/in/paulapiccard/',
#     'description': 'Proud #Startup Owner. #NewYork-er. #WomeninTech & #Cybersecurity Advocate. #DigitalMarketing \nPractitioner & #SocialMedia #Influencer http://spotrus.com',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': False,
#     'followers_count': 43562,
#     'friends_count': 10013,
#     'listed_count': 1261,
#     'favourites_count': 85910,
#     'statuses_count': 93265,
#     'created_at': 'Mon May 02 17:47:28 +0000 2011',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': 'ADB0DE',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': True,
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1007344781050048512/tThzjCI__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1007344781050048512/tThzjCI__normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/291831562/1561767259',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': 'This app helps the visually impaired identify surroundings\n#AI #ArtificialIntelligence #ML #ComputerVision #IoT #Tech\n\n@MikeQuindazzi @SpirosMargaris @jblefevre60 @sallyeaves \n@diioannid  @andi_staub @HaroldSinnott @Hal_Good \n@andi_staub @THEAdamGabriel https://t.co/zewG5mCDcO',
#     'display_text_range': [0, 253],
#     'entities': {'hashtags': [{'text': 'AI', 'indices': [59, 62]},
#       {'text': 'ArtificialIntelligence', 'indices': [63, 86]},
#       {'text': 'ML', 'indices': [87, 90]},
#       {'text': 'ComputerVision', 'indices': [91, 106]},
#       {'text': 'IoT', 'indices': [107, 111]},
#       {'text': 'Tech', 'indices': [112, 117]}],
#      'urls': [],
#      'user_mentions': [{'screen_name': 'MikeQuindazzi',
#        'name': 'Mike Quindazzi ✨',
#        'id': 2344530218,
#        'id_str': '2344530218',
#        'indices': [119, 133]},
#       {'screen_name': 'SpirosMargaris',
#        'name': 'Spiros Margaris',
#        'id': 2711212681,
#        'id_str': '2711212681',
#        'indices': [134, 149]},
#       {'screen_name': 'jblefevre60',
#        'name': 'Jean-Baptiste Lefevre',
#        'id': 4374719908,
#        'id_str': '4374719908',
#        'indices': [150, 162]},
#       {'screen_name': 'sallyeaves',
#        'name': 'Dr. Sally Eaves #1510SF',
#        'id': 3131243261,
#        'id_str': '3131243261',
#        'indices': [163, 174]},
#       {'screen_name': 'diioannid',
#        'name': 'Dimitris Ioannides',
#        'id': 338489470,
#        'id_str': '338489470',
#        'indices': [176, 186]},
#       {'screen_name': 'andi_staub',
#        'name': 'Andreas Staub',
#        'id': 298704683,
#        'id_str': '298704683',
#        'indices': [188, 199]},
#       {'screen_name': 'HaroldSinnott',
#        'name': 'Harold Sinnott 💥',
#        'id': 202590356,
#        'id_str': '202590356',
#        'indices': [200, 214]},
#       {'screen_name': 'Hal_Good',
#        'name': 'Harold (Hal) Good',
#        'id': 29005683,
#        'id_str': '29005683',
#        'indices': [215, 224]},
#       {'screen_name': 'andi_staub',
#        'name': 'Andreas Staub',
#        'id': 298704683,
#        'id_str': '298704683',
#        'indices': [226, 237]},
#       {'screen_name': 'THEAdamGabriel',
#        'name': 'Adam Gabriel, #TOP🔝 #Influencer📡',
#        'id': 408898240,
#        'id_str': '408898240',
#        'indices': [238, 253]}],
#      'symbols': [],
#      'media': [{'id': 1161013535188684802,
#        'id_str': '1161013535188684802',
#        'indices': [254, 277],
#        'additional_media_info': {'title': '',
#         'description': '',
#         'embeddable': True,
#         'monetizable': False},
#        'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1161013535188684802/img/stcxFdsyDKSMaiYA.jpg',
#        'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1161013535188684802/img/stcxFdsyDKSMaiYA.jpg',
#        'url': 'https://t.co/zewG5mCDcO',
#        'display_url': 'pic.twitter.com/zewG5mCDcO',
#        'expanded_url': 'https://twitter.com/Paula_Piccard/status/1161253568885809152/video/1',
#        'type': 'video',
#        'video_info': {'aspect_ratio': [1, 1],
#         'duration_millis': 90132,
#         'variants': [{'bitrate': 432000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1161013535188684802/vid/320x320/9ur1mdEKtAY9P_cY.mp4?tag=13'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/amplify_video/1161013535188684802/pl/24Vws8g41MVEFJLi.m3u8?tag=13'},
#          {'bitrate': 1280000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1161013535188684802/vid/720x720/Xl8SIy-I-rjj41nP.mp4?tag=13'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1161013535188684802/vid/480x480/qEvQ-TSH5LrIYmqR.mp4?tag=13'}]},
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 720, 'h': 720, 'resize': 'fit'},
#         'large': {'w': 720, 'h': 720, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1161013535188684802,
#        'id_str': '1161013535188684802',
#        'indices': [254, 277],
#        'additional_media_info': {'title': '',
#         'description': '',
#         'embeddable': True,
#         'monetizable': False},
#        'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1161013535188684802/img/stcxFdsyDKSMaiYA.jpg',
#        'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1161013535188684802/img/stcxFdsyDKSMaiYA.jpg',
#        'url': 'https://t.co/zewG5mCDcO',
#        'display_url': 'pic.twitter.com/zewG5mCDcO',
#        'expanded_url': 'https://twitter.com/Paula_Piccard/status/1161253568885809152/video/1',
#        'type': 'video',
#        'video_info': {'aspect_ratio': [1, 1],
#         'duration_millis': 90132,
#         'variants': [{'bitrate': 432000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1161013535188684802/vid/320x320/9ur1mdEKtAY9P_cY.mp4?tag=13'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/amplify_video/1161013535188684802/pl/24Vws8g41MVEFJLi.m3u8?tag=13'},
#          {'bitrate': 1280000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1161013535188684802/vid/720x720/Xl8SIy-I-rjj41nP.mp4?tag=13'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1161013535188684802/vid/480x480/qEvQ-TSH5LrIYmqR.mp4?tag=13'}]},
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 720, 'h': 720, 'resize': 'fit'},
#         'large': {'w': 720, 'h': 720, 'resize': 'fit'}}}]}},
#    'quote_count': 20,
#    'reply_count': 7,
#    'retweet_count': 185,
#    'favorite_count': 275,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [59, 62]},
#      {'text': 'ArtificialIntelligence', 'indices': [63, 86]},
#      {'text': 'ML', 'indices': [87, 90]},
#      {'text': 'ComputerVision', 'indices': [91, 106]},
#      {'text': 'IoT', 'indices': [107, 111]}],
#     'urls': [{'url': 'https://t.co/c56ivW7ZiG',
#       'expanded_url': 'https://twitter.com/i/web/status/1161253568885809152',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [113, 136]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'AI', 'indices': [78, 81]},
#     {'text': 'ArtificialIntelligence', 'indices': [82, 105]},
#     {'text': 'ML', 'indices': [106, 109]},
#     {'text': 'ComputerVision', 'indices': [110, 125]},
#     {'text': 'IoT', 'indices': [126, 130]},
#     {'text': 'Tech', 'indices': [131, 136]}],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'Paula_Piccard',
#      'name': 'Paula Piccard 🇵🇷 🇺🇸',
#      'id': 291831562,
#      'id_str': '291831562',
#      'indices': [3, 17]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'matching_rules': [{'tag': None}]},
#  {'created_at': 'Tue Aug 13 23:59:59 +0000 2019',
#   'id': 1161427209774612480,
#   'id_str': '1161427209774612480',
#   'text': 'RT @KirkDBorne: #ReinforcementLearning and #DeepLearning — Explained in One Picture — with this AlphaGo Zero cheat sheet: https://t.co/03OD…',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2561936749,
#    'id_str': '2561936749',
#    'name': 'Juan Manuel Solana M',
#    'screen_name': 'JuanMSolana',
#    'location': None,
#    'url': None,
#    'description': 'Economista interesado en el mundo.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 839,
#    'friends_count': 964,
#    'listed_count': 46,
#    'favourites_count': 970,
#    'statuses_count': 23928,
#    'created_at': 'Wed Jun 11 19:08:50 +0000 2014',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/806552839761891328/qvYpa6s3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/806552839761891328/qvYpa6s3_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2561936749/1504490358',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Aug 13 23:14:00 +0000 2019',
#    'id': 1161415635915726849,
#    'id_str': '1161415635915726849',
#    'text': '#ReinforcementLearning and #DeepLearning — Explained in One Picture — with this AlphaGo Zero cheat sheet:… https://t.co/fazm3O6nQW',
#    'display_text_range': [0, 140],
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 534563976,
#     'id_str': '534563976',
#     'name': 'Kirk Borne',
#     'screen_name': 'KirkDBorne',
#     'location': 'Booz Allen Hamilton',
#     'url': 'http://www.linkedin.com/in/kirkdborne',
#     'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top Big Data Science & #AI Influencer. Astrophysicist (Views are my own) http://rocketdatascience.org/ 📊🔭',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': True,
#     'followers_count': 239517,
#     'friends_count': 17470,
#     'listed_count': 7886,
#     'favourites_count': 189741,
#     'statuses_count': 106094,
#     'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1540268609',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': '#ReinforcementLearning and #DeepLearning — Explained in One Picture — with this AlphaGo Zero cheat sheet: https://t.co/03ODwog3pY\n———————\n#BigData #DataScience #TPU #TensorFlow #MachineLearning #AI #Algorithms #abdsc\n———————\n+See this book: https://t.co/d1ZHk0a8nv https://t.co/eGs2jmoRAp',
#     'display_text_range': [0, 264],
#     'entities': {'hashtags': [{'text': 'ReinforcementLearning',
#        'indices': [0, 22]},
#       {'text': 'DeepLearning', 'indices': [27, 40]},
#       {'text': 'BigData', 'indices': [138, 146]},
#       {'text': 'DataScience', 'indices': [147, 159]},
#       {'text': 'TPU', 'indices': [160, 164]},
#       {'text': 'TensorFlow', 'indices': [165, 176]},
#       {'text': 'MachineLearning', 'indices': [177, 193]},
#       {'text': 'AI', 'indices': [194, 197]},
#       {'text': 'Algorithms', 'indices': [198, 209]},
#       {'text': 'abdsc', 'indices': [210, 216]}],
#      'urls': [{'url': 'https://t.co/03ODwog3pY',
#        'expanded_url': 'https://dy.si/1FAEC',
#        'display_url': 'dy.si/1FAEC',
#        'indices': [106, 129]},
#       {'url': 'https://t.co/d1ZHk0a8nv',
#        'expanded_url': 'https://amzn.to/2SBpiET',
#        'display_url': 'amzn.to/2SBpiET',
#        'indices': [241, 264]}],
#      'user_mentions': [],
#      'symbols': [],
#      'media': [{'id': 1160640567811956738,
#        'id_str': '1160640567811956738',
#        'indices': [265, 288],
#        'media_url': 'http://pbs.twimg.com/media/EBtscnRW4AIbU5a.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EBtscnRW4AIbU5a.jpg',
#        'url': 'https://t.co/eGs2jmoRAp',
#        'display_url': 'pic.twitter.com/eGs2jmoRAp',
#        'expanded_url': 'https://twitter.com/KirkDBorne/status/1161415635915726849/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 1080, 'resize': 'fit'},
#         'large': {'w': 2000, 'h': 1800, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 612, 'resize': 'fit'}}},
#       {'id': 1160640598258438150,
#        'id_str': '1160640598258438150',
#        'indices': [265, 288],
#        'media_url': 'http://pbs.twimg.com/media/EBtseYsXUAYAd6J.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EBtseYsXUAYAd6J.jpg',
#        'url': 'https://t.co/eGs2jmoRAp',
#        'display_url': 'pic.twitter.com/eGs2jmoRAp',
#        'expanded_url': 'https://twitter.com/KirkDBorne/status/1161415635915726849/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 293, 'h': 360, 'resize': 'fit'},
#         'medium': {'w': 293, 'h': 360, 'resize': 'fit'},
#         'small': {'w': 293, 'h': 360, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1160640567811956738,
#        'id_str': '1160640567811956738',
#        'indices': [265, 288],
#        'media_url': 'http://pbs.twimg.com/media/EBtscnRW4AIbU5a.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EBtscnRW4AIbU5a.jpg',
#        'url': 'https://t.co/eGs2jmoRAp',
#        'display_url': 'pic.twitter.com/eGs2jmoRAp',
#        'expanded_url': 'https://twitter.com/KirkDBorne/status/1161415635915726849/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 1080, 'resize': 'fit'},
#         'large': {'w': 2000, 'h': 1800, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 612, 'resize': 'fit'}}},
#       {'id': 1160640598258438150,
#        'id_str': '1160640598258438150',
#        'indices': [265, 288],
#        'media_url': 'http://pbs.twimg.com/media/EBtseYsXUAYAd6J.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EBtseYsXUAYAd6J.jpg',
#        'url': 'https://t.co/eGs2jmoRAp',
#        'display_url': 'pic.twitter.com/eGs2jmoRAp',
#        'expanded_url': 'https://twitter.com/KirkDBorne/status/1161415635915726849/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 293, 'h': 360, 'resize': 'fit'},
#         'medium': {'w': 293, 'h': 360, 'resize': 'fit'},
#         'small': {'w': 293, 'h': 360, 'resize': 'fit'}}}]}},
#    'quote_count': 1,
#    'reply_count': 0,
#    'retweet_count': 23,
#    'favorite_count': 31,
#    'entities': {'hashtags': [{'text': 'ReinforcementLearning',
#       'indices': [0, 22]},
#      {'text': 'DeepLearning', 'indices': [27, 40]}],
#     'urls': [{'url': 'https://t.co/fazm3O6nQW',
#       'expanded_url': 'https://twitter.com/i/web/status/1161415635915726849',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [107, 130]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'ReinforcementLearning',
#      'indices': [16, 38]},
#     {'text': 'DeepLearning', 'indices': [43, 56]}],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'KirkDBorne',
#      'name': 'Kirk Borne',
#      'id': 534563976,
#      'id_str': '534563976',
#      'indices': [3, 14]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'matching_rules': [{'tag': None}]},
#  {'created_at': 'Tue Aug 13 23:59:59 +0000 2019',
#   'id': 1161427207614545920,
#   'id_str': '1161427207614545920',
#   'text': '10 Ways Machine Learning Is Revolutionizing Manufacturing In 2019\nhttps://t.co/dMwY0PF7Cb | via @Forbes… https://t.co/hVSlXphahb',
#   'source': '<a href="http://www.hubspot.com/" rel="nofollow">HubSpot</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 154544264,
#    'id_str': '154544264',
#    'name': 'Blue Whale Apps',
#    'screen_name': 'BlueWhaleInc',
#    'location': 'Washington, DC',
#    'url': 'https://www.bluewhaleapps.com',
#    'description': 'A full-cycle #appdevelopment, #uxdesign, #digitaltransformation, and #mobiledevelopment services provider based in #Washington, #Florida, and #NewYork.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 9082,
#    'friends_count': 544,
#    'listed_count': 360,
#    'favourites_count': 121,
#    'statuses_count': 2911,
#    'created_at': 'Fri Jun 11 14:34:46 +0000 2010',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'EBEBEB',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#    'profile_background_tile': True,
#    'profile_link_color': '990000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'F3F3F3',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1103350192747806721/LiSntpB8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1103350192747806721/LiSntpB8_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/154544264/1379610749',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': '10 Ways Machine Learning Is Revolutionizing Manufacturing In 2019\nhttps://t.co/dMwY0PF7Cb | via @Forbes\n\n#machinelearning #ai #artificialintelligence #bigdata #deeplearning #iot #datascience #tech #digitaltransformation #internetofthings #ml',
#    'display_text_range': [0, 241],
#    'entities': {'hashtags': [{'text': 'machinelearning',
#       'indices': [105, 121]},
#      {'text': 'ai', 'indices': [122, 125]},
#      {'text': 'artificialintelligence', 'indices': [126, 149]},
#      {'text': 'bigdata', 'indices': [150, 158]},
#      {'text': 'deeplearning', 'indices': [159, 172]},
#      {'text': 'iot', 'indices': [173, 177]},
#      {'text': 'datascience', 'indices': [178, 190]},
#      {'text': 'tech', 'indices': [191, 196]},
#      {'text': 'digitaltransformation', 'indices': [197, 219]},
#      {'text': 'internetofthings', 'indices': [220, 237]},
#      {'text': 'ml', 'indices': [238, 241]}],
#     'urls': [{'url': 'https://t.co/dMwY0PF7Cb',
#       'expanded_url': 'https://hubs.ly/H0kdCC50',
#       'display_url': 'hubs.ly/H0kdCC50',
#       'indices': [66, 89]}],
#     'user_mentions': [{'screen_name': 'Forbes',
#       'name': 'Forbes',
#       'id': 91478624,
#       'id_str': '91478624',
#       'indices': [96, 103]}],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/dMwY0PF7Cb',
#      'expanded_url': 'https://hubs.ly/H0kdCC50',
#      'display_url': 'hubs.ly/H0kdCC50',
#      'indices': [66, 89]},
#     {'url': 'https://t.co/hVSlXphahb',
#      'expanded_url': 'https://twitter.com/i/web/status/1161427207614545920',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [105, 128]}],
#    'user_mentions': [{'screen_name': 'Forbes',
#      'name': 'Forbes',
#      'id': 91478624,
#      'id_str': '91478624',
#      'indices': [96, 103]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'matching_rules': [{'tag': None}]},
#  {'created_at': 'Tue Aug 13 23:59:55 +0000 2019',
#   'id': 1161427193605607427,
#   'id_str': '1161427193605607427',
#   'text': 'RT @DonnaWR8: Google has an Artificial Intelligence Lab in Beijing, China AND yet refuses to work with the US Pentagon ... They’re working…',
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 779112394391851009,
#    'id_str': '779112394391851009',
#    'name': 'Amos Moses⭐⭐⭐',
#    'screen_name': 'BeverlyMcCord2',
#    'location': 'East Texas USA',
#    'url': None,
#    'description': 'Conservative, happily married country girl,Jesus #1,  Patriot,#MAGA,\nNO LISTS Libs blocked, No DMs, fb @GenFlynn@RyanAFournier #2ThumbsUp',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 21814,
#    'friends_count': 22153,
#    'listed_count': 18,
#    'favourites_count': 21239,
#    'statuses_count': 231578,
#    'created_at': 'Fri Sep 23 00:17:24 +0000 2016',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/964898261416005632/aLPDhY6n_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/964898261416005632/aLPDhY6n_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/779112394391851009/1546828307',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Aug 12 16:07:10 +0000 2019',
#    'id': 1160945833212305409,
#    'id_str': '1160945833212305409',
#    'text': 'Google has an Artificial Intelligence Lab in Beijing, China AND yet refuses to work with the US Pentagon ... They’r… https://t.co/JeB6OpeoXW',
#    'display_text_range': [0, 140],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2922345639,
#     'id_str': '2922345639',
#     'name': 'DONNA WARREN ⭐️🌟⭐️',
#     'screen_name': 'DonnaWR8',
#     'location': None,
#     'url': None,
#     'description': 'Humor | Delegate | TRUMP | Memes Spoken Here | Top 200 | #WWG1WGA | Truth Speaker | Critical Thinker | SHADOWBAN Verified | Saved By GRACE | John 3:16',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': False,
#     'followers_count': 104553,
#     'friends_count': 12957,
#     'listed_count': 370,
#     'favourites_count': 163781,
#     'statuses_count': 182058,
#     'created_at': 'Mon Dec 15 03:30:20 +0000 2014',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1148856519968141312/jxECfAYo_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1148856519968141312/jxECfAYo_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2922345639/1562390945',
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': 'Google has an Artificial Intelligence Lab in Beijing, China AND yet refuses to work with the US Pentagon ... They’re working with the Chinese government AGAINST our own instead. \n\nIsn’t that considered TREASON?? \n\n#WakeUpAmerica \n#BigTechIsTheThreat https://t.co/u5XdXg1oxQ',
#     'display_text_range': [0, 249],
#     'entities': {'hashtags': [{'text': 'WakeUpAmerica', 'indices': [214, 228]},
#       {'text': 'BigTechIsTheThreat', 'indices': [230, 249]}],
#      'urls': [],
#      'user_mentions': [],
#      'symbols': [],
#      'media': [{'id': 1160945827646496768,
#        'id_str': '1160945827646496768',
#        'indices': [250, 273],
#        'media_url': 'http://pbs.twimg.com/media/EByCFExXYAAEPgJ.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EByCFExXYAAEPgJ.jpg',
#        'url': 'https://t.co/u5XdXg1oxQ',
#        'display_url': 'pic.twitter.com/u5XdXg1oxQ',
#        'expanded_url': 'https://twitter.com/DonnaWR8/status/1160945833212305409/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 523, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 924, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 1173, 'h': 1524, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1160945827646496768,
#        'id_str': '1160945827646496768',
#        'indices': [250, 273],
#        'media_url': 'http://pbs.twimg.com/media/EByCFExXYAAEPgJ.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EByCFExXYAAEPgJ.jpg',
#        'url': 'https://t.co/u5XdXg1oxQ',
#        'display_url': 'pic.twitter.com/u5XdXg1oxQ',
#        'expanded_url': 'https://twitter.com/DonnaWR8/status/1160945833212305409/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 523, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 924, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 1173, 'h': 1524, 'resize': 'fit'}}}]}},
#    'quote_count': 12,
#    'reply_count': 32,
#    'retweet_count': 528,
#    'favorite_count': 509,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/JeB6OpeoXW',
#       'expanded_url': 'https://twitter.com/i/web/status/1160945833212305409',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'DonnaWR8',
#      'name': 'DONNA WARREN ⭐️🌟⭐️',
#      'id': 2922345639,
#      'id_str': '2922345639',
#      'indices': [3, 12]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'matching_rules': [{'tag': None}]},
#  {'created_at': 'Tue Aug 13 23:59:54 +0000 2019',
#   'id': 1161427189767770112,
#   'id_str': '1161427189767770112',
#   'text': 'RT @SentienceLab: https://t.co/kzIvTvDYDZ #AI #ArtificialIntelligence #MachineLearning #Technology \n#innovation #digital #sentiencelab  #Re…',
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 747917675301572608,
#    'id_str': '747917675301572608',
#    'name': 'Jay Chance',
#    'screen_name': 'JayChance5',
#    'location': 'Off Shore',
#    'url': None,
#    'description': 'Bizounours Realism',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 465,
#    'friends_count': 3833,
#    'listed_count': 0,
#    'favourites_count': 3065,
#    'statuses_count': 46151,
#    'created_at': 'Tue Jun 28 22:20:44 +0000 2016',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/887135954867277824/QxNV4uXW_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/887135954867277824/QxNV4uXW_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/747917675301572608/1550435967',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Aug 13 20:39:00 +0000 2019',
#    'id': 1161376630029373444,
#    'id_str': '1161376630029373444',
#    'text': 'https://t.co/kzIvTvDYDZ #AI #ArtificialIntelligence #MachineLearning #Technology \n#innovation #digital… https://t.co/NrbQEiHCXA',
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 719784694217359360,
#     'id_str': '719784694217359360',
#     'name': 'SentienceLab',
#     'screen_name': 'SentienceLab',
#     'location': 'Amsterdam, The Netherlands',
#     'url': None,
#     'description': 'We Deliver AI Solutions That Work.\n#b2b #AI #Design #Implementation #Training #Consulting #ArtificialIntelligence #MachineLearning #ComputerVision',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': False,
#     'followers_count': 1277,
#     'friends_count': 3118,
#     'listed_count': 194,
#     'favourites_count': 466,
#     'statuses_count': 1662,
#     'created_at': 'Tue Apr 12 07:10:18 +0000 2016',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_link_color': '25274D',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1134024667541442560/dPQno7Ey_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1134024667541442560/dPQno7Ey_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/719784694217359360/1559566023',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': 'https://t.co/kzIvTvDYDZ #AI #ArtificialIntelligence #MachineLearning #Technology \n#innovation #digital #sentiencelab  #Retail \n#ComputerVision #Enterprise #CIO #DigitalTransformation #virtualassistant \n#StrategicManagement #bigdata #datascience #deeplearning #industry #business',
#     'display_text_range': [0, 278],
#     'entities': {'hashtags': [{'text': 'AI', 'indices': [24, 27]},
#       {'text': 'ArtificialIntelligence', 'indices': [28, 51]},
#       {'text': 'MachineLearning', 'indices': [52, 68]},
#       {'text': 'Technology', 'indices': [69, 80]},
#       {'text': 'innovation', 'indices': [82, 93]},
#       {'text': 'digital', 'indices': [94, 102]},
#       {'text': 'sentiencelab', 'indices': [103, 116]},
#       {'text': 'Retail', 'indices': [118, 125]},
#       {'text': 'ComputerVision', 'indices': [127, 142]},
#       {'text': 'Enterprise', 'indices': [143, 154]},
#       {'text': 'CIO', 'indices': [155, 159]},
#       {'text': 'DigitalTransformation', 'indices': [160, 182]},
#       {'text': 'virtualassistant', 'indices': [183, 200]},
#       {'text': 'StrategicManagement', 'indices': [202, 222]},
#       {'text': 'bigdata', 'indices': [223, 231]},
#       {'text': 'datascience', 'indices': [232, 244]},
#       {'text': 'deeplearning', 'indices': [245, 258]},
#       {'text': 'industry', 'indices': [259, 268]},
#       {'text': 'business', 'indices': [269, 278]}],
#      'urls': [{'url': 'https://t.co/kzIvTvDYDZ',
#        'expanded_url': 'https://buff.ly/2Lu1VNH',
#        'display_url': 'buff.ly/2Lu1VNH',
#        'indices': [0, 23]}],
#      'user_mentions': [],
#      'symbols': []}},
#    'quote_count': 0,
#    'reply_count': 0,
#    'retweet_count': 2,
#    'favorite_count': 6,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [24, 27]},
#      {'text': 'ArtificialIntelligence', 'indices': [28, 51]},
#      {'text': 'MachineLearning', 'indices': [52, 68]},
#      {'text': 'Technology', 'indices': [69, 80]},
#      {'text': 'innovation', 'indices': [82, 93]},
#      {'text': 'digital', 'indices': [94, 102]}],
#     'urls': [{'url': 'https://t.co/kzIvTvDYDZ',
#       'expanded_url': 'https://buff.ly/2Lu1VNH',
#       'display_url': 'buff.ly/2Lu1VNH',
#       'indices': [0, 23]},
#      {'url': 'https://t.co/NrbQEiHCXA',
#       'expanded_url': 'https://twitter.com/i/web/status/1161376630029373444',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [104, 127]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'und'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'AI', 'indices': [42, 45]},
#     {'text': 'ArtificialIntelligence', 'indices': [46, 69]},
#     {'text': 'MachineLearning', 'indices': [70, 86]},
#     {'text': 'Technology', 'indices': [87, 98]},
#     {'text': 'innovation', 'indices': [100, 111]},
#     {'text': 'digital', 'indices': [112, 120]},
#     {'text': 'sentiencelab', 'indices': [121, 134]}],
#    'urls': [{'url': 'https://t.co/kzIvTvDYDZ',
#      'expanded_url': 'https://buff.ly/2Lu1VNH',
#      'display_url': 'buff.ly/2Lu1VNH',
#      'indices': [18, 41]}],
#    'user_mentions': [{'screen_name': 'SentienceLab',
#      'name': 'SentienceLab',
#      'id': 719784694217359360,
#      'id_str': '719784694217359360',
#      'indices': [3, 16]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'und',
#   'matching_rules': [{'tag': None}]},
#  {'created_at': 'Tue Aug 13 23:59:51 +0000 2019',
#   'id': 1161427175473651712,
#   'id_str': '1161427175473651712',
#   'text': 'World’s First Smart Mini-City to be Built in Las Vegas. The new $7.5B project will include renewable energies from… https://t.co/3aeqhv9xWU',
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16666454,
#    'id_str': '16666454',
#    'name': 'Bill Schrier',
#    'screen_name': 'billschrier',
#    'location': 'Seattle',
#    'url': 'http://about.me/billschrier',
#    'description': 'Living in the Admiral District of West Seattle in the Other Washington. Working with civic technology and public safety technology. Tweets are my own.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 7115,
#    'friends_count': 1927,
#    'listed_count': 657,
#    'favourites_count': 12515,
#    'statuses_count': 24866,
#    'created_at': 'Thu Oct 09 14:04:35 +0000 2008',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '59C4C9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1601330005/Bill-sm_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1601330005/Bill-sm_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16666454/1398872508',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': 'World’s First Smart Mini-City to be Built in Las Vegas. The new $7.5B project will include renewable energies from solar/wind/water/kinetic, autonomous vehicles, #AI and #AR  and #IoT, robotics, supertrees, and self-healing concrete structures. Supertrees? https://t.co/7dmvNyEItK',
#    'display_text_range': [0, 280],
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [162, 165]},
#      {'text': 'AR', 'indices': [170, 173]},
#      {'text': 'IoT', 'indices': [179, 183]}],
#     'urls': [{'url': 'https://t.co/7dmvNyEItK',
#       'expanded_url': 'https://www.archdaily.com/922885/worlds-first-smart-mini-city-to-be-built-in-las-vegas',
#       'display_url': 'archdaily.com/922885/worlds-…',
#       'indices': [257, 280]}],
#     'user_mentions': [],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 1,
#   'retweet_count': 0,
#   'favorite_count': 3,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/3aeqhv9xWU',
#      'expanded_url': 'https://twitter.com/i/web/status/1161427175473651712',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'matching_rules': [{'tag': None}]},
#  {'created_at': 'Tue Aug 13 23:59:44 +0000 2019',
#   'id': 1161427146314829828,
#   'id_str': '1161427146314829828',
#   'text': 'By incorporating a fictional book that reflects a future driven by Artificial Intelligence into high school curricu… https://t.co/EyneEmfWeb',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 64144208,
#    'id_str': '64144208',
#    'name': 'Gimba Kakanda',
#    'screen_name': 'gimbakakanda',
#    'location': 'London | Abuja | Minna ',
#    'url': None,
#    'description': 'RIP, Imam Imam |Writer, foreign policy junkie, political economist, justice and equality advocate, University of Iowa’s IWP fellow, and currently at @LSENews.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': True,
#    'followers_count': 71705,
#    'friends_count': 1098,
#    'listed_count': 163,
#    'favourites_count': 2393,
#    'statuses_count': 51039,
#    'created_at': 'Sun Aug 09 09:18:56 +0000 2009',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#    'profile_background_tile': False,
#    'profile_link_color': '89C9FA',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1156694964493062144/NWt6nm5b_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1156694964493062144/NWt6nm5b_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/64144208/1490173217',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '00e55e2b4c491c5f',
#    'url': 'https://api.twitter.com/1.1/geo/id/00e55e2b4c491c5f.json',
#    'place_type': 'city',
#    'name': 'Abuja',
#    'full_name': 'Abuja, Nigeria',
#    'country_code': 'NG',
#    'country': 'Nigeria',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[7.304554, 8.961887],
# ...
#     'verified': False,
#     'followers_count': 475,
#     'friends_count': 108,
#     'listed_count': 21,
#     'favourites_count': 41,
#     'statuses_count': 351,
#     'created_at': 'Fri Mar 25 19:32:58 +0000 2011',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': 'B2DFDA',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_tile': False,
#     'profile_link_color': '93A644',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/2845505778/fb5b7c9b5bc8b4cedbfc747f9aef9d08_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2845505778/fb5b7c9b5bc8b4cedbfc747f9aef9d08_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/272071431/1359395179',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': "Can artificial intelligence (AI) save the elephant? We think so. Check out this recent episode of NPR's Planet Money where ELP director, Dr. Peter Wrege, discusses how AI is helping us track elephants and where they are being poached. #WorldElephantDay\n\nhttps://t.co/jmXkldZx4z",
#     'display_text_range': [0, 277],
#     'entities': {'hashtags': [{'text': 'WorldElephantDay',
#        'indices': [235, 252]}],
#      'urls': [{'url': 'https://t.co/jmXkldZx4z',
#        'expanded_url': 'https://www.npr.org/2019/08/09/749938354/episode-932-deep-learning-with-the-elephants',
#        'display_url': 'npr.org/2019/08/09/749…',
#        'indices': [254, 277]}],
#      'user_mentions': [],
#      'symbols': []}},
#    'quote_count': 1,
#    'reply_count': 0,
#    'retweet_count': 4,
#    'favorite_count': 12,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/0TqJwu2WNG',
#       'expanded_url': 'https://twitter.com/i/web/status/1161069260480897034',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'ElephantRumbles',
#      'name': 'ElephantRumbles',
#      'id': 272071431,
#      'id_str': '272071431',
#      'indices': [3, 19]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'matching_rules': [{'tag': None}]},
#  {'created_at': 'Tue Aug 13 23:59:23 +0000 2019',
#   'id': 1161427055927582725,
#   'id_str': '1161427055927582725',
#   'text': 'RT @ahmedxQB: RT first please \nhelp our seniors from university of Khartoum to attend the deep learning indaba at Nairobi \n#deeplearn2019…',
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 552774638,
#    'id_str': '552774638',
#    'name': 'Mohamed Almakki',
#    'screen_name': 'mmakky1',
#    'location': 'Sudan',
#    'url': None,
#    'description': 'Philomath | Aspiring Software Engineer | ML/DL enthusiast',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 248,
#    'friends_count': 722,
#    'listed_count': 0,
#    'favourites_count': 4956,
#    'statuses_count': 1378,
#    'created_at': 'Fri Apr 13 15:16:34 +0000 2012',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1158525465512071168/D5GiVYr3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1158525465512071168/D5GiVYr3_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/552774638/1550786047',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Aug 13 17:47:17 +0000 2019',
#    'id': 1161333415049871360,
#    'id_str': '1161333415049871360',
#    'text': 'RT first please \nhelp our seniors from university of Khartoum to attend the deep learning indaba at Nairobi… https://t.co/45HVmXeGUx',
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2786366133,
#     'id_str': '2786366133',
#     'name': 'optimus',
#     'screen_name': 'ahmedxQB',
#     'location': 'cybertron ',
#     'url': 'https://www.instagram.com/ahmed_qb_prime?r=nametag',
#     'description': "your answers aren't here || drawing the frustration out || uofk 017 || art & anime",
#     'translator_type': 'none',
#     'protected': False,
#     'verified': False,
#     'followers_count': 294,
#     'friends_count': 566,
#     'listed_count': 1,
#     'favourites_count': 1966,
#     'statuses_count': 6613,
#     'created_at': 'Fri Sep 26 22:28:23 +0000 2014',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1098015301105577984/UEqpqd1w_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1098015301105577984/UEqpqd1w_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2786366133/1554876179',
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': 'RT first please \nhelp our seniors from university of Khartoum to attend the deep learning indaba at Nairobi \n#deeplearn2019 \n#Ai #programming #programminglife #RiseWithUs \nhttps://t.co/NjEjfcX2mP',
#     'display_text_range': [0, 195],
#     'entities': {'hashtags': [{'text': 'deeplearn2019', 'indices': [109, 123]},
#       {'text': 'Ai', 'indices': [125, 128]},
#       {'text': 'programming', 'indices': [129, 141]},
#       {'text': 'programminglife', 'indices': [142, 158]},
#       {'text': 'RiseWithUs', 'indices': [159, 170]}],
#      'urls': [{'url': 'https://t.co/NjEjfcX2mP',
#        'expanded_url': 'https://www.gofundme.com/f/invest-in-africa039s-futuresend-students-to-indaba?utm_source=customer&utm_medium=copy_link&utm_campaign=p_cp+share-sheet',
#        'display_url': 'gofundme.com/f/invest-in-af…',
#        'indices': [172, 195]}],
#      'user_mentions': [],
#      'symbols': []}},
#    'quote_count': 0,
#    'reply_count': 0,
#    'retweet_count': 8,
#    'favorite_count': 10,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/45HVmXeGUx',
#       'expanded_url': 'https://twitter.com/i/web/status/1161333415049871360',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [109, 132]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'deeplearn2019', 'indices': [123, 137]}],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'ahmedxQB',
#      'name': 'optimus',
#      'id': 2786366133,
#      'id_str': '2786366133',
#      'indices': [3, 12]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'matching_rules': [{'tag': None}]},
#  {'created_at': 'Tue Aug 13 23:59:23 +0000 2019',
#   'id': 1161427055927582725,
#   'id_str': '1161427055927582725',
#   'text': 'RT @ahmedxQB: RT first please \nhelp our seniors from university of Khartoum to attend the deep learning indaba at Nairobi \n#deeplearn2019…',
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 552774638,
#    'id_str': '552774638',
#    'name': 'Mohamed Almakki',
#    'screen_name': 'mmakky1',
#    'location': 'Sudan',
#    'url': None,
#    'description': 'Philomath | Aspiring Software Engineer | ML/DL enthusiast',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 248,
#    'friends_count': 722,
#    'listed_count': 0,
#    'favourites_count': 4956,
#    'statuses_count': 1378,
#    'created_at': 'Fri Apr 13 15:16:34 +0000 2012',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1158525465512071168/D5GiVYr3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1158525465512071168/D5GiVYr3_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/552774638/1550786047',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Aug 13 17:47:17 +0000 2019',
#    'id': 1161333415049871360,
#    'id_str': '1161333415049871360',
#    'text': 'RT first please \nhelp our seniors from university of Khartoum to attend the deep learning indaba at Nairobi… https://t.co/45HVmXeGUx',
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2786366133,
#     'id_str': '2786366133',
#     'name': 'optimus',
#     'screen_name': 'ahmedxQB',
#     'location': 'cybertron ',
#     'url': 'https://www.instagram.com/ahmed_qb_prime?r=nametag',
#     'description': "your answers aren't here || drawing the frustration out || uofk 017 || art & anime",
#     'translator_type': 'none',
#     'protected': False,
#     'verified': False,
#     'followers_count': 294,
#     'friends_count': 566,
#     'listed_count': 1,
#     'favourites_count': 1966,
#     'statuses_count': 6613,
#     'created_at': 'Fri Sep 26 22:28:23 +0000 2014',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1098015301105577984/UEqpqd1w_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1098015301105577984/UEqpqd1w_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2786366133/1554876179',
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': 'RT first please \nhelp our seniors from university of Khartoum to attend the deep learning indaba at Nairobi \n#deeplearn2019 \n#Ai #programming #programminglife #RiseWithUs \nhttps://t.co/NjEjfcX2mP',
#     'display_text_range': [0, 195],
#     'entities': {'hashtags': [{'text': 'deeplearn2019', 'indices': [109, 123]},
#       {'text': 'Ai', 'indices': [125, 128]},
#       {'text': 'programming', 'indices': [129, 141]},
#       {'text': 'programminglife', 'indices': [142, 158]},
#       {'text': 'RiseWithUs', 'indices': [159, 170]}],
#      'urls': [{'url': 'https://t.co/NjEjfcX2mP',
#        'expanded_url': 'https://www.gofundme.com/f/invest-in-africa039s-futuresend-students-to-indaba?utm_source=customer&utm_medium=copy_link&utm_campaign=p_cp+share-sheet',
#        'display_url': 'gofundme.com/f/invest-in-af…',
#        'indices': [172, 195]}],
#      'user_mentions': [],
#      'symbols': []}},
#    'quote_count': 0,
#    'reply_count': 0,
#    'retweet_count': 8,
#    'favorite_count': 10,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/45HVmXeGUx',
#       'expanded_url': 'https://twitter.com/i/web/status/1161333415049871360',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [109, 132]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'deeplearn2019', 'indices': [123, 137]}],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'ahmedxQB',
#      'name': 'optimus',
#      'id': 2786366133,
#      'id_str': '2786366133',
#      'indices': [3, 12]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'matching_rules': [{'tag': None}]}]

# %%
query = '("Artificial Intelligence") OR #ArtificialIntelligence OR #AI lang:en'

# get 500 tweets from 2007 using fullarchive API
AI_tweets_2007 = get_tweets_premium(api, 5, 'fullarchive', 'development', query = query, 
                                    fromDate = '200701010000', toDate = '200801010000', 
                                    maxResults = 100)

# %%
len(AI_tweets_2007)  # only 200 found
# Out:
# 199

# %%
for tweet in AI_tweets_2007:
    tweet['year'] = 2007  # keep track of year for later compilation
    print(tweet['text'] + '\n')
# Out:
# Anyone involved in artificial intelligence work? Specifically, anyone know of any AI system that can RECOGNISE puns in natural language?
#
# 読書中 Paradigms of Artificial Intelligence Programming: Case Studies in Common Lisp
#
# Update on geekgirl LOVE AND SEX WITH ROBOTS: If advances in artificial intelligence cont.. http://tinyurl.com/2vykx7
#
# "A.I. Artificial Intelligence" a Speilberg movie based on a Brian Aldiss  short story is very creepy.  Like it mo' better than "I Robot."
#
# Paradigms of Artificial Intelligence Programming を注文した♪
#
# @moltz: chill it, dude. Your twirly brain wave patterns are fucking with the lesbian sexbot artificial intelligence orbs production line
#
# Leadership and Artificial Intelligence: Two new issues of Shrinkrapradio were published shortly one aft.. http://tinyurl.com/327etm
#
# Class: Intro to Artificial Intelligence and Computer Simulation. Official Grade: A. Yay!
#
# aibits: Artificial Intelligence for Advanced Problem Solving Techniques http://tinyurl.com/2rfndt
#
# Most excellent. Artificial intelligence arrives "to pick your pocket" ;D... Of course. Truly human: http://tinyurl.com/2y7lth
#
# Artificial Intelligence is no match for Natural Stupidity. (essa esta agora colada no meu monitor)
#
# artificial intelligence
#
# @MrFresh LOL that explains the bug in Yar's Artificial Intelligence module. I will have to upgrade to the iRobot version 2.0
#
# aibits: Is mathematics the new artificial intelligence? http://tinyurl.com/2cexb6
#
# You are a real boy. At least as real as I've ever made one. *Artificial Intelligence: AI (2001)
#
# Taking a break from my artificial intelligence.
#
# The a posteriori probability of Artificial Intelligence involving a lot of probability is 1.0.
#
# Oh boy... Just added "Paradigms of Artificial Intelligence Programming: Case Studies in Common Lisp" to my amazon wish list
#
# NPR: Artificial Intelligence Enters Brave New World http://tinyurl.com/yw5y59
#
# It's really different...john is an AI  artificial intelligence robot
#
# Just finished watching Artificial Intelligence - I thought it was supposed to be a happy movie, not leave me brawling my eyes out.
#
# Reading: "OpenAi - - Creating the standard for Artificial Intelligence" (http://tinyurl.com/g8m3j)
#
# Reading: "MachineBrain Robots, Robotics, Artificial Intelligence, AI, and Kits." (http://tinyurl.com/2tm9vo)
#
# reading "Artificial Intelligence: a modern approach" from Stuart Russell and Peter Norvig... spectacular!!
#
# Working on artificial intelligence expert system. pretty much done.
#
# Facebook was cutting off an ad. I was getting "Commemorate World AI Day" Rather than "AIDS." I was excited about artificial intelligence.
#
# “Artificial Intelligence (AI) agents will pull information for us on the basis of parameters we establish and control.”
#
# Bizarre electronic instrument is part artificial intelligence, part sex toy: http://tinyurl.com/38vnw4
#
# aibits: Inside Galcon: Python, Game Development and Artificial Intelligence http://tinyurl.com/yq8w5t
#
# From my feeds Web 3.0 Artificial Intelligence Agents will be Conversation Agents http://tinyurl.com/2swsvc
#
# the fear of artificial intelligence. &gt;&lt;
#
# Reading: "Robot Info, Robotics, Virtual Humans, How to build robot kits, Artificial Intelligence" (http://tinyurl.com/2ls9av)
#
# Reading: "WHAT IS ARTIFICIAL INTELLIGENCE?" (http://tinyurl.com/4nzad)
#
# aibits: JOB: Research Fellowship in Artificial Intelligence, ESA's Advanced Concepts Team, deadline.. http://tinyurl.com/35r2s4
#
# The Open Artificial Intelligence Journal http://fon.gs/toaij. Una revista ¿abierta?¿social?¿wikinómica?. No sé, pero voy a mandar algo.
#
# Amazon Artificial Artificial Intelligence: http://www.mturk.com/mturk/welcome
#
# Having trouble getting focused. Instituting artificial intelligence initiative: break out the Red Bull!
#
# @chrisbrogan next: commerce and relationships driven by socially-driven meta data, augmented by artificial intelligence / predictive apps
#
# Sitting in artificial intelligence learning about utility.
#
# starting to build a new http://www.aibits.com everything about Robots and Artificial Intelligence
#
# fr. globeandmail.com Romancing the robot: Artificial intelligence? Think artificia.. http://tinyurl.com/29dr6w
#
# Globe: Romancing the robot: Artificial intelligence? Think artificial nookie. One expert says .. http://tinyurl.com/29dr6w
#
# My teacher can even make artificial intelligence boring. He is really good. At sucking. A lot.
#
# [del.icio.us] Polyworld: Using Evolution to Design Artificial Intelligence http://tinyurl.com/2j26vt
#
# 2nd paper ... Artificial Intelligence .. again ... sux!!
#
# Weekly Access Top10: The day when Google is not and "artificial
# intelligence" installs "artificial consciousness" - ITmedia
# enterprise h ...
#
# Weekly Access Top10: The day when Google is not and "artificial
# intelligence" installs "artificial consciousness" - ITmedia
# enterprise h ...
#
# I can write an artificial intelligence, but can't remember anything for myself. Is this where humanity is heading?
#
# talking about twitter as the future of humanity and the probable foundation of superhuman artificial intelligence
#
# One of my favorite advisees just let me know she wants to do an indep study with me on math and artificial intelligence. cool!
#
# and what would *that* be: :
# "Using artificial intelligence, virtual worlds and nanotechnology to cure disease." hmmm. i'll have to chew onit
#
# it's hard to be a master of software that has its own artificial intelligence.
#
# A Robot Bride by 2050?: An artificial intelligence researcher predicts that robotics will make such dramati.. http://tinyurl.com/25z5jo
#
# link: MIT Computer Science and Artificial Intelligence Laboratory http://tinyurl.com/tzyea
#
# Open Day RuG was great, I really consider studying Artificial Intelligence now. Angry Whopper menu at the Burger King was great, too :)
#
# Can Facebook feed its ad brains?: Social-networking site expected to tap artificial intelligence to d.. http://tinyurl.com/2sz7ku
#
# "ALife as an approach to Artificial Intelligence" by Larry Yaeger, SOI in Borders, Nov. 8 at 7-8:30p
#
# @tristynu It had decided to switch me from phone notification to IMs instead. Entirely its doing, must be developing artificial intelligence
#
# "Artificial Intelligence usually beats natural stupidity" :)
#
# cognitive psychology& artificial intelligence for 2 weeks
#
# RIght now, I wish Artificial Intelligence could be Artificially Interesting.
#
# rebajando Artificial Intelligence
#
# @j2bryson: Actually it was the reference to artificial intelligence, once a pet field of mine.
#
# This book on mathematical methods in artificial intelligence is awesome: http://tinyurl.com/2zcvoq
#
# or MIT Computer Science and Artificial Intelligence Laboratory
# The Stata Center, Building 32 - 32 Vassar Street - Cambridge, MA 02139 - USA
#
# Brief Introduction to Educational Implications of Artificial Intelligence: Quoted: Section: Miscellane.. http://tinyurl.com/3b6mat
#
# Brief Introduction to Educational Implications of Artificial Intelligence: Section: Miscellaneous This.. http://tinyurl.com/2x82zj
#
# Brief Introduction to Educational Implications of Artificial Intelligence: Section: Miscellaneous This..
#
# Brief Introduction to Educational Implications of Artificial Intelligence: Quoted: Section: Miscellane.. http://tinyurl.com/3b6mat
#
# Brief Introduction to Educational Implications of Artificial Intelligence: Section: Miscellaneous This.. http://tinyurl.com/2x82zj
#
# @FoxyTunesDJ Listening Total Science – Going in Circles (Artificial Intelligence remix) http://tinyurl.com/27yfv9
#
# @blakehall Just let AI GORE do it, that Artificial Intelligence Fu will provide us all with a life of leisure
#
# Am I the only one who sees 'Al' in reference to Al Gore all over the net and think they're congratulating AI as in Artificial Intelligence?
#
# a huevo consegui Artificial Intelligence! la estaba buscando
#
# Will you one day marry a robot?: David Levy, a British artificial intelligence researcher and international.. http://tinyurl.com/2sk52o
#
# One day one of your Twitter friends may marry a robot... so says a British artificial intelligence researcher http://tinyurl.com/2la8qe
#
# database. operating systems. artificial intelligence. software engineering II. &gt;&lt;
#
# WhiteSmoke launches world’s most advanced text enrichment software to enhance written English
#
# Artificial intelligence delivers unriva ...
#
# @bkocik, lol -- that's really impressive Artificial Intelligence :-)
#
# preparing syllabus of artificial intelligence course
#
# @FoxyTunesDJ Listening Total Science – Going in Circles (Artificial Intelligence remix) http://tinyurl.com/27yfv9
#
# the previous message was sent in response to twitterim asking what I'm doing.  the new wave of artificial intelligence is upon us.
#
# artificial intelligence
# the book was in excellent condition.it arrived on time.i am q
# http://www.amazon.com/dp/0137903952
#
# Skimming through Wired's "Geekipedia". Michael Arrington is listed between "Apple Smackdown" and "Artificial Intelligence".
#
# New Post up "Artificial Intelligence on Second Life," Interview with Ben Goertzel & David orban, very cool   if I say so myself! http:// ...
#
# Reading: "Artificial Intelligence - Computers and the Internet - Technology - Science - New York Times" (http://tinyurl.com/2osf9g)
#
# artificial intelligence exam coming up. brrr... :(
#
# reading: Artificial Intelligence - Computers and the Internet - Technology - Science - New York .. http://tinyurl.com/2bwpwo
#
# watched 1408 + Artificial Intelligence
#
# watched 1408 + Artificial Intelligence
#
# reading about "Apple Co-Founder Looks to Robotics and Artificial Intelligence" http://urltea.com/1k8s - go Wozniak!
#
# IT'S HERE! Stupid Artificial Intelligence http://tinyurl.com/2y2ssy
#
# Asking questions in Artificial Intelligence Class.
#
# Artificial intelligence search engine "Powerset", part technology for
# the first time generality release http://tinyurl.com/25xofg
#
# [ENGDT] Cognitive Code shows off SILVIA artificial intelligence platform: Filed under: Robots Cog.. http://tinyurl.com/2f9dpu
#
# Online worlds may help develop artificial intelligence - http://tinyurl.com/3ddfoq
#
# Is anyone using Web 2.0 to develop a model for artificial intelligence?
#
# Artificial intelligence is no match for natural stupidity
#
# Artificial intelligence is no match for natural stupidity
#
# reading the speaker brief, The Nature of Self-Improving Artificial Intelligence, from the Singularity conf. It's much sexier than it sounds.
#
# lunchtime lecture on artificial intelligence - cars that drive themselves
#
# Goin to grab food, then gonna go talk about artificial intelligence and culture
#
# New post: Artificial Artificial Intelligence Tries To Track Down Steve Fossett (http://www.teleactivities.net/node/2422)
#
# i discovered that Artificial intelligence is no match for natural stupidity
#
# Browsing: SiliconValley.com - Venture capitalist: We need to prepare for artificial intelligence . http://tinyurl.com/2dcwmt
#
# This might sound diabolical, but it's how I'm approaching a topic in the saijo project about artificial intelligence...
#
# that Artificial Intelligence will solve crime, bad choices by individuals, etc.
#
# New post: Re-examine future of artificial intelligence (http://tinyurl.com/27jzez)
#
# Will artificial intelligence take over world? http://tinyurl.com/23bgog/c/a/2007/09/07/MNK8RUU7J.DTL&type=tech
#
# "If you invent a breakthrough in artificial intelligence, so machines can learn, that is worth 10 Microsofts." -Bill Gates
#
# playing - the last track from "Bytes" by The Black Dog, on Warp's Artificial Intelligence series.
#
# Barney Pell: Pathways to artificial intelligence - http://tinyurl.com/3yh9b5
#
# Joined the Singularity Institute for Artificial Intelligence http://rurl.org/8d6
#
# Eliezer Yudkowsky's artificial intelligence theories are my new new jam. http://www.singinst.org/upload/CFAI/ Dude's kinda verbose though...
#
# Studying artificial intelligence, having just returned from a lovely Chinese lunch.
#
# If only artificial intelligence could solve the pattern of the forthcoming housing crash...
#
# Pondering patterns and artificial intelligence efficiency
#
# Philosophizing on the limits of artificial intelligence. Pointed out that I'd be rather happy to see more "natural" one first.
#
# kevin if you find any neuroscience or anything saying "automata theory" "artificial intelligence", etc, GIMME
#
# "Artificial Intelligence is no match for natural stupidity." - Unknown http://tqpage.com/239
#
# @adrian - so it's like an animatronic turtle with artificial intelligence...that's amazing.
#
# Saga newspaper, with Twitter wind service all support artificial
# intelligence "vinegar chicken" participation - ITmedia News http://feed ...
#
# Saga newspaper, with Twitter wind service all support artificial
# intelligence "vinegar chicken" participation - ITmedia News http://feed ...
#
# Saga newspaper, with Twitter wind service all support artificial
# intelligence "vinegar chicken" participation - ITmedia News http://feed ...
#
# Saga newspaper, with Twitter wind service all support artificial
# intelligence "vinegar chicken" participation - ITmedia News http://feed ...
#
# Saga newspaper, with Twitter wind service all support artificial
# intelligence "vinegar chicken" participation - ITmedia News http://feed ...
#
# Saga newspaper, with Twitter wind service all support artificial
# intelligence "vinegar chicken" participation - ITmedia News http://feed ...
#
# Saga newspaper, with Twitter wind service all support artificial
# intelligence "vinegar chicken" participation - ITmedia News http://feed ...
#
# Saga newspaper, with Twitter wind service all support artificial
# intelligence "vinegar chicken" participation - ITmedia News http://feed ...
#
# Saga newspaper, with Twitter wind service all support artificial
# intelligence "vinegar chicken" participation - ITmedia News http://feed ...
#
# Saga newspaper, with Twitter wind service all support artificial
# intelligence "vinegar chicken" participation - ITmedia News http://feed ...
#
# Saga newspaper, with Twitter wind service all support artificial
# intelligence "vinegar chicken" participation - ITmedia News http://feed ...
#
# The title is "What Humans Do with Artificial Intelligence" and I can't wait. OK, now I'm done for today.
#
# Passing, after 7 years, with a Computer Science with Artificial Intelligence degree and a Computer and Networking HND. Too geeky?
#
# Computer takes on poker aces: A showdown pitting human brains against artificial intelligence goes ahead th.. http://tinyurl.com/2frw2c
#
# Donald Michie, 83, Theorist of Artificial Intelligence, Dies http://tinyurl.com/ywqmho
#
# Dedric Mauriac :Artificial Intelligence in the 60's http://bloghud.com/id/11469
#
# @mollywood Only if it has artificial intelligence.
#
# King me! Science of winning checkers solved: Researchers say find a key to artificial intelligence.. http://tinyurl.com/ytm4yy
#
# Artificial Intelligence: A Modern Approach By Stuart Russell and Peter Norvig:
# 	Artificial Intelligence: .. http://tinyurl.com/ywcqjx
#
# or perhaps a time traveling tool? ouch, i just blew a fuse contemplating that. a time machine with it's own artificial intelligence. havoc!
#
# Reading Russell and Norvig's "Artificial Intelligence: A Modern Approach"
#
# New Artificial Intelligence teaches language to consumers: Contact: [Eunice Charles]
# 	   phone:  1 81.. http://tinyurl.com/2mobwf
#
# New Artificial Intelligence  tool for the DIY and BIG Box industry to cut labor cost while aiding your.. http://tinyurl.com/2ka424
#
# @kmakice I instructed the facebook artificial intelligence and personality app to let you log in.
#
# code 3d (Artificial Intelligence Script)
#
# Reviewing the philosophy of artificial intelligence
#
# artificial intelligence
#
# I'm talking to Paul McCartney. LOL! Artificial intelligence can be fun.
#
# there is a point when most artificial intelligence systems start being as good as humans
#
# artificial intelligence
#
# sleep, then artificial intelligence final
#
# New blog post: Encore Posting: Singularity Institute for Artificial Intelligence http://metavalent.info/?p=578
#
# Artificial intelligence exam in... 3 hours.
#
# First exam tomorrow... Not looking forward to that. Why am I doing Artificial Intelligence again? -sigh-
#
# Artificial Intelligence In The Uncanny Valley (http://tinyurl.com/2xabay)
#
# "Artificial Intelligence is no match for natural stupidity." - Unknown http://tqpage.com/239
#
# Artificial intelligence homework
#
# is doing some secret and terrible things regarding computer systems and artificial intelligence. Yes, I'm studying...
#
# Artificial intelligence is no match for natural stupidity.
#
# Singularity Institute for Artificial Intelligence -- http://scouta.com/faves/jLJ4YVnRZCH
#
# Singularity Institute for Artificial Intelligence -- http://scouta.com/faves/jLJ4YVnRZCH
#
# Computers cannot replace humans as they may master artificial intelligence, but they will never match genuine stupidity.
#
# Preparing for Artificial Intelligence Paper .
#
# @Benj & Benj Yeah, I remember the first time I heard one of the Artificial Intelligence comps in the early nineties - those sounds were just
#
# (Artificial) Intelligence in Virtual Worlds (http://tinyurl.com/2abdxo)
#
# Prepping for an exam in Artificial Intelligence
#
# Researching Artificial Intelligence in gaming for work while listening to Jenn Grant http://www.myspace.com/jenngrant1
#
# ever heard of artificial artificial intelligence? http://www.mturk.com/mturk/welcome
#
# What's on my mind? Hrm. Acting. Artificial Intelligence. Fiction. Rain. Shell for my truck. Staffing.
#
# In an artificial intelligence lecture.
#
# good grief, and I thought that "AI" still meant Artificial Intelligence. geek.  nerd. But I'm ok with that. :S
#
# Symbolic Artificial Intelligence lecture...
#
# Amazon's Mechanical Turk (a.k.a. "Artificial Artificial Intelligence") (http://tinyurl.com/yv2mlv)
#
# Debate about Artificial Intelligence going on all of the suddon...
#
# @mitchjoel i like that one, humans can translate into contexts which is still a limited capacity of artificial intelligence
#
# programming plugins, artificial intelligence, css, java, javascript, html, php and mysql. trying to find other cool coders.
#
# Testers are strange creatures. They enter wrong data and expect correct results. How? I’m not doing an artificial intelligence system.
#
# Artificial Intelligence
#
# Artificial Intelligence
#
# Found via The Institute of Work Weblog, important NYT (March 25) article 'Artificial Intelligence, With Help From the Humans' http://tinyurl
#
# Attending talk by Michael Mateas, visiting speaker from UCSC, on design and artificial intelligence in Cyber-torium.
#
# Searching for collaboration with Students of Artificial Intelligence
#
# Numenta - Has Artificial Intelligence Arrived? : http://tinyurl.com/3c9a2x
#
# Watching 'Yellow' an awesome artificial intelligence short-film.
#
# http://www.thoughtware.tv/site/show/38
#
# Reading: "NYT Artificial Intelligence, With Help From the Humans (mentions LIS degree)" (http://tinyurl.com/3d46dt)
#
# Reading: Numenta - Has Artificial Intelligence Arrived?
# http://tinyurl.com/3c9a2x
#
# Interesting sub-project in sight. Dusting off my Artificial Intelligence book.
#
# watched AI Artificial Intelligence, good movie, kinda tells what life is all about, the simple complexities of love
#
# Artificial Intelligence, With Help From the Humans (Jason Pontin/New York Times) http://tinyurl.com/29qevz
#
# Slipstream: Artificial Intelligence, With Help From the Humans http://tinyurl.com/36hslp
#
# I finally got back to working on Project Kilt Huntin'. This is the hardest part, the enemies artificial intelligence...
#
# Considering interesting developments in neurology and artificial intelligence. I would say it isn't brain surgery. But it is.
#
# [Opposable Thumbs] Artificial intelligence: the rise of the drivatar - http://tinyurl.com/2ykmcv
#
# In a class (artificial intelligence).
#
# In a class (artificial intelligence).
#
# Artificial Intelligence... when does it stop boy?
#
# Artificial Intelligence, Operating Systems...
#
# Chit chatting with my mates& MSG. The calm before another pointless exam : Artificial intelligence

# %%
# get 500 tweets from 2008 using fullarchive API
AI_tweets_2008 = get_tweets_premium(api, 5, 'fullarchive', 'development', query = query, 
                                    fromDate = '200801010000', toDate = '200901010000', 
                                    maxResults = 100)

# %%
for tweet in AI_tweets_2008:
    tweet['year'] = 2008
len(AI_tweets_2008)
# Out:
# 495

# %%
# get 500 tweets from 2009 using fullarchive API
AI_tweets_2009 = get_tweets_premium(api, 5, 'fullarchive', 'development', query = query, 
                                    fromDate = '200901010000', toDate = '201001010000', 
                                    maxResults = 100)

# %%
for tweet in AI_tweets_2009:
    tweet['year'] = 2009
len(AI_tweets_2009)
# Out:
# 491

# %%
# get 500 tweets from 2010 using fullarchive API
AI_tweets_2010 = get_tweets_premium(api, 5, 'fullarchive', 'development', query = query, 
                                    fromDate = '201001010000', toDate = '201101010000', 
                                    maxResults = 100)

# %%
for tweet in AI_tweets_2010:
    tweet['year'] = 2010
len(AI_tweets_2010)
# Out:
# 496

# %%
# get 500 tweets from 2011 using fullarchive API
AI_tweets_2011 = get_tweets_premium(api, 5, 'fullarchive', 'development', query = query, 
                                    fromDate = '201101010000', toDate = '201201010000', 
                                    maxResults = 100)

# %%
for tweet in AI_tweets_2011:
    tweet['year'] = 2011
len(AI_tweets_2011)
# Out:
# 499

# %%
# get 500 tweets from 2012 using fullarchive API
AI_tweets_2012 = get_tweets_premium(api, 5, 'fullarchive', 'development', query = query, 
                                    fromDate = '201201010000', toDate = '201301010000', 
                                    maxResults = 100)

# %%
for tweet in AI_tweets_2012:
    tweet['year'] = 2012
len(AI_tweets_2012)
# Out:
# 495

# %%
# get 500 tweets from 2013 using fullarchive API
AI_tweets_2013 = get_tweets_premium(api, 5, 'fullarchive', 'development', query = query, 
                                    fromDate = '201301010000', toDate = '201401010000', 
                                    maxResults = 100)

# %%
for tweet in AI_tweets_2013:
    tweet['year'] = 2013
len(AI_tweets_2013)
# Out:
# 499

# %%
# get 500 tweets from 2014 using fullarchive API
AI_tweets_2014 = get_tweets_premium(api, 5, 'fullarchive', 'development', query = query, 
                                    fromDate = '201401010000', toDate = '201501010000', 
                                    maxResults = 100)

# %%
for tweet in AI_tweets_2014:
    tweet['year'] = 2014
len(AI_tweets_2014)
# Out:
# 499

# %%
# get 500 tweets from 2016 using fullarchive API
AI_tweets_2016 = get_tweets_premium(api, 5, 'fullarchive', 'development', query = query, 
                                    fromDate = '201601010000', toDate = '201701010000', 
                                    maxResults = 100)

# %%
for tweet in AI_tweets_2016:
    tweet['year'] = 2016
len(AI_tweets_2016)
# Out:
# 497

# %%
# get 300 tweets from 2017 using fullarchive API (not 500 to avoid going over Sandbox request limits)
AI_tweets_2017 = get_tweets_premium(api, 3, 'fullarchive', 'development', query = query, 
                                    fromDate = '201701010000', toDate = '201801010000', 
                                    maxResults = 100)

# %%
for tweet in AI_tweets_2017:
    tweet['year'] = 2017
len(AI_tweets_2017)
# Out:
# 297

# %%
# get 500 tweets from 2018 using fullarchive API
AI_tweets_2018 = get_tweets_premium(api, 5, 'fullarchive', 'development', query = query, 
                                    fromDate = '201801010000', toDate = '201901010000', 
                                    maxResults = 100)

# %%
for tweet in AI_tweets_2018:
    tweet['year'] = 2018
len(AI_tweets_2018)
# Out:
# 495

# %%
# get 500 tweets from 2019 using 30day API
AI_tweets_2019 = get_tweets_premium(api, 5, '30day', 'development', query = query, 
                                    fromDate = '201907170000', toDate = '201908150000', 
                                    maxResults = 100)

# %%
for tweet in AI_tweets_2019:
    tweet['year'] = 2019
len(AI_tweets_2019)
# Out:
# 498

# %%
# compile results
tweets_all_years = AI_tweets_2007 + AI_tweets_2008 + AI_tweets_2009 + AI_tweets_2010 +\
                   AI_tweets_2011 + AI_tweets_2012 + AI_tweets_2013 + AI_tweets_2014 +\
                   AI_tweets_2016 + AI_tweets_2017 + AI_tweets_2018 + AI_tweets_2019

print(type(tweets_all_years), len(tweets_all_years))
# Out:
# <class 'list'> 5460

# %%
tweets_all_years[0:5]
# Out:
# [{'created_at': 'Sat Dec 29 22:43:06 +0000 2007',
#   'id': 544845252,
#   'id_str': '544845252',
#   'text': 'Anyone involved in artificial intelligence work? Specifically, anyone know of any AI system that can RECOGNISE puns in natural language?',
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 5967392,
#    'id_str': '5967392',
#    'name': 'Mark Harrison',
#    'screen_name': 'MarkHarrisonUK',
#    'location': 'Malham Close, Crawley, West Su',
#    'url': 'http://markharrison.wordpress.com',
#    'description': 'Serial entrepreneur, currently running a boutique programming shop in London specialising in regulated markets.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 757,
#    'friends_count': 600,
#    'listed_count': 23,
#    'favourites_count': 8,
#    'statuses_count': 1414,
#    'created_at': 'Fri May 11 16:49:34 +0000 2007',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '0000FF',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'C62200',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/41715182/Mark_-_2006_formal_pic_-_small_-_unedited_normal.JPG',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/41715182/Mark_-_2006_formal_pic_-_small_-_unedited_normal.JPG',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'matching_rules': [{'tag': None}],
#   'year': 2007,
#   '_id': ObjectId('5d571491b3fda1745453e12f')},
#  {'created_at': 'Tue Dec 25 13:29:53 +0000 2007',
#   'id': 532130162,
#   'id_str': '532130162',
#   'text': '読書中 Paradigms of Artificial Intelligence Programming: Case Studies in Common Lisp',
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4344931,
#    'id_str': '4344931',
#    'name': 'ヤーンポッチナズムナイルピネロピルニャー',
#    'screen_name': 'quek',
#    'location': 'JP (Japan, Japan)',
#    'url': 'http://read-eval-print.blogspot.com/',
#    'description': 'ヤーンポッチナズムナイルピネロピルニャール卿バッハナスカレシン  Common Lisp 合理的無政府主義',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 606,
#    'friends_count': 620,
#    'listed_count': 56,
#    'favourites_count': 2164,
#    'statuses_count': 10690,
#    'created_at': 'Thu Apr 12 12:11:01 +0000 2007',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'B2DFDA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_tile': False,
#    'profile_link_color': '93A644',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/579855763725647872/AUpq9mu2_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/579855763725647872/AUpq9mu2_normal.png',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'matching_rules': [{'tag': None}],
#   'year': 2007,
#   '_id': ObjectId('5d571491b3fda1745453e130')},
#  {'created_at': 'Tue Dec 25 11:33:43 +0000 2007',
#   'id': 531926162,
#   'id_str': '531926162',
#   'text': 'Update on geekgirl LOVE AND SEX WITH ROBOTS: If advances in artificial intelligence cont.. http://tinyurl.com/2vykx7',
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1835601,
#    'id_str': '1835601',
#    'name': 'geekgirl Ⓥ',
#    'screen_name': 'rosiex',
#    'location': 'Melbourne',
#    'url': 'http://www.geekgirl.com.au/',
#    'description': "#geekgirl founder. publisher of australia's longest running website. metal cupcake & vegan ❤️🤓🤖 likes art, robots, tech & fun! dislikes (don't get me started)",
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 4178,
#    'friends_count': 4204,
#    'listed_count': 202,
#    'favourites_count': 11324,
#    'statuses_count': 19289,
#    'created_at': 'Thu Mar 22 04:37:08 +0000 2007',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/538518405561589760/K2hpppQ7_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/538518405561589760/K2hpppQ7_normal.jpeg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1835601/1398401809',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'matching_rules': [{'tag': None}],
#   'year': 2007,
#   '_id': ObjectId('5d571491b3fda1745453e131')},
#  {'created_at': 'Sat Dec 22 15:20:03 +0000 2007',
#   'id': 524153882,
#   'id_str': '524153882',
#   'text': '"A.I. Artificial Intelligence" a Speilberg movie based on a Brian Aldiss  short story is very creepy.  Like it mo\' better than "I Robot."',
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 11141582,
#    'id_str': '11141582',
#    'name': 'Tom Novak',
#    'screen_name': 'rebelsofmars',
#    'location': 'Barsoom!',
#    'url': 'http://www.thesuddencurve.com',
#    'description': "Microblogging Retro Sci Fi and Fantastic Adventures in the Burroughs' Tradition",
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 232,
#    'friends_count': 217,
#    'listed_count': 20,
#    'favourites_count': 2,
#    'statuses_count': 2304,
#    'created_at': 'Thu Dec 13 21:21:26 +0000 2007',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_link_color': '3D0F9E',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/665684731/rom_rocketeer_icon_400_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/665684731/rom_rocketeer_icon_400_normal.jpg',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'matching_rules': [{'tag': None}],
#   'year': 2007,
#   '_id': ObjectId('5d571491b3fda1745453e132')},
#  {'created_at': 'Sat Dec 22 11:29:44 +0000 2007',
#   'id': 523822582,
#   'id_str': '523822582',
#   'text': 'Paradigms of Artificial Intelligence Programming を注文した♪',
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4344931,
#    'id_str': '4344931',
#    'name': 'ヤーンポッチナズムナイルピネロピルニャー',
#    'screen_name': 'quek',
#    'location': 'JP (Japan, Japan)',
#    'url': 'http://read-eval-print.blogspot.com/',
#    'description': 'ヤーンポッチナズムナイルピネロピルニャール卿バッハナスカレシン  Common Lisp 合理的無政府主義',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 606,
#    'friends_count': 620,
#    'listed_count': 56,
#    'favourites_count': 2164,
#    'statuses_count': 10690,
#    'created_at': 'Thu Apr 12 12:11:01 +0000 2007',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'B2DFDA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_tile': False,
#    'profile_link_color': '93A644',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/579855763725647872/AUpq9mu2_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/579855763725647872/AUpq9mu2_normal.png',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'ja',
#   'matching_rules': [{'tag': None}],
#   'year': 2007,
#   '_id': ObjectId('5d571491b3fda1745453e133')}]

# %%
tweets_all_years_df = tweets_to_df(tweets_all_years)
tweets_all_years_df.head()
# Out:
#           id             user_name user_screenname  \
# 0  544845252         Mark Harrison  MarkHarrisonUK
# 1  532130162  ヤーンポッチナズムナイルピネロピルニャー            quek
# 2  531926162            geekgirl Ⓥ          rosiex
# 3  524153882             Tom Novak    rebelsofmars
# 4  523822582  ヤーンポッチナズムナイルピネロピルニャー            quek
#
#                                     user_description  user_friends  \
# 0  Serial entrepreneur, currently running a bouti...           600
# 1  ヤーンポッチナズムナイルピネロピルニャール卿バッハナスカレシン  Common Lisp 合...           620
# 2  #geekgirl founder. publisher of australia's lo...          4204
# 3  Microblogging Retro Sci Fi and Fantastic Adven...           217
# 4  ヤーンポッチナズムナイルピネロピルニャール卿バッハナスカレシン  Common Lisp 合...           620
#
#    user_followers  user_favorites  retweets                            date  \
# 0             757               8         0  Sat Dec 29 22:43:06 +0000 2007
# 1             606            2164         0  Tue Dec 25 13:29:53 +0000 2007
# 2            4178           11324         0  Tue Dec 25 11:33:43 +0000 2007
# 3             232               2         0  Sat Dec 22 15:20:03 +0000 2007
# 4             606            2164         0  Sat Dec 22 11:29:44 +0000 2007
#
#                          location geocode hashtags  \
# 0  Malham Close, Crawley, West Su    None      NaN
# 1               JP (Japan, Japan)    None      NaN
# 2                       Melbourne    None      NaN
# 3                        Barsoom!    None      NaN
# 4               JP (Japan, Japan)    None      NaN
#
#                                                tweet
# 0  Anyone involved in artificial intelligence wor...
# 1  読書中 Paradigms of Artificial Intelligence Progr...
# 2  Update on geekgirl LOVE AND SEX WITH ROBOTS: I...
# 3  "A.I. Artificial Intelligence" a Speilberg mov...
# 4  Paradigms of Artificial Intelligence Programmi...

# %%
# pickle and save the results as CSV
pd.to_pickle(tweets_all_years_df, 'tweets_all_years_df.pickle')
tweets_all_years_df.to_csv('tweets_all_years_df.csv')

# %%
# request 24,000 tweets from 30day API (takes ~10 minutes)
AI_tweets_2019_large = get_tweets_premium(api, 240, '30day', 'development', query = query, 
                                          fromDate = '201907170000', toDate = '201908150000', 
                                          maxResults = 100)

# %%
len(AI_tweets_2019_large)
# Out:
# 23864

# %%
for tweet in AI_tweets_2019_large:
    tweet['year'] = 2019

# %%
tweets_2019_large_df = tweets_to_df(AI_tweets_2019_large)
tweets_2019_large_df.head()
# Out:
#                     id          user_name user_screenname  \
# 0  1161789559715196928  Barbara Frietchie       Barbaren7
# 1  1161789531328319488        ILoveUiPath     ILoveUiPath
# 2  1161789508771336195           Max 🇫🇷🇺🇸  girardmaxime33
# 3  1161789506426671104           willynet        willynet
# 4  1161789505889820672           Max 🇫🇷🇺🇸  girardmaxime33
#
#                                     user_description  user_friends  \
# 0  "Shoot, if you must, this old gray head But sp...          1191
# 1  #RPA lover. I believe that technology is here ...          4966
# 2  Head of Data&Traffic http://Jeux.com and Actip...          1139
# 3  In love with Stella, Father of Cecilia, Ximena...          3124
# 4  Head of Data&Traffic http://Jeux.com and Actip...          1139
#
#    user_followers  user_favorites  retweets                            date  \
# 0             937           52448         0  Wed Aug 14 23:59:50 +0000 2019
# 1            2453             533         0  Wed Aug 14 23:59:43 +0000 2019
# 2            2925            2152         2  Wed Aug 14 23:59:38 +0000 2019
# 3            1667           11819         0  Wed Aug 14 23:59:37 +0000 2019
# 4            2925            2152         2  Wed Aug 14 23:59:37 +0000 2019
#
#            location geocode                                  hashtags  \
# 0              None    None                                       NaN
# 1              None    None                             [AI, SXSWEDU]
# 2  Bordeaux, France    None  [AI, FutureofWork, ANN, MachineLearning]
# 3   Santiago, Chile    None                               [MSInspire]
# 4  Bordeaux, France    None                        [BigData, PwC, AI]
#
#                                                tweet
# 0  RT @rising_serpent: Once you combine this giga...
# 1  RT @UiPath: Do you believe in the power of #AI...
# 2  RT MikeQuindazzi: 7 #AI terms in the #Futureof...
# 3  RT @Microsoft: What if technology could help y...
# 4  RT MikeQuindazzi: #BigData sets unlocking $45 ...

# %%
pd.to_pickle(tweets_2019_large_df, 'tweets_2019_large_df.pickle')
tweets_2019_large_df.to_csv('tweets_2019_large_df.csv')

# %%
# open MongoDB daemon and connect with pymongo

#!mongod
client = MongoClient()
client.list_database_names()
# Out:
# ['admin', 'books', 'config', 'local', 'outings']

# %%
twitter = client['twitter']  # make new db
twitter.create_collection('tweets_all_years')  # make new collection
twitter.create_collection('tweets_2019_large')
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'twitter'), 'tweets_2019_large')

# %%
twitter.list_collection_names()
# Out:
# ['tweets_2019_large', 'tweets_all_years']

# %%
all_years = twitter.tweets_all_years
large_2019 = twitter.tweets_2019_large

# %%
all_years.insert_many(tweets_all_years)  # insert fullarchive tweets to 'tweets_all_years' collection

# %%
large_2019.insert_many(AI_tweets_2019_large)  # insert 30day tweets to 'tweets_2019_large' collection

# %%
print(all_years.count_documents({}), large_2019.count_documents({}))
# Out:
# 5460 23864
